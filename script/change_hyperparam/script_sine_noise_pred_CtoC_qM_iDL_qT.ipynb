# %%
#!/usr/bin/env python
# encoding: utf-8
'''
@author: ivy
@contact: ivyivyzhao77@gmail.com
@software: PyCharm 2022.3
@file: script_Uzel2022_qM_iDL_qT.py
@time: 2023/3/14 11:21
'''

from train._utils import *

########################### Hyperparameters #########################
time_step = 20
BATCH_SIZE = 128
LR = 0.01
EPOCH = 500
num_worms_train = 1
smoothed = False
#####################################################################

model = get_model(OmegaConf.load("../../conf/model.yaml"))
print(model)
optimizer = torch.optim.SGD(model.parameters(), lr=LR)
criterion = torch.nn.MSELoss()

dataset = get_dataset(OmegaConf.load("../../conf/dataset.yaml"))

print(dataset["worm0"].keys())

plt.plot(dataset["worm0"]["calcium_data"][:, 1])
plt.plot(dataset["worm0"]["residual_calcium"][:, 1])
plt.show()
# Out:
# Model: NetworkLSTM(
#   (lstm): LSTM(302, 302, batch_first=True)
#   (linear): Linear(in_features=302, out_features=302, bias=True)
# )
#
# NetworkLSTM(
#   (lstm): LSTM(302, 302, batch_first=True)
#   (linear): Linear(in_features=302, out_features=302, bias=True)
# )
# Chosen dataset(s): ['sine_noise']
# Num. worms: 6
# Worm names: ['worm0', 'worm1', 'worm2', 'worm3', 'worm4', 'worm5']
#
#
# dict_keys(['dataset', 'worm', 'calcium_data', 'smooth_calcium_data', 'residual_calcium', 'residual_smooth_calcium', 'neuron_to_idx', 'idx_to_neuron', 'max_time', 'time_in_seconds', 'dt', 'named_neurons_mask', 'named_neuron_to_idx', 'idx_to_named_neuron', 'num_neurons', 'num_named_neurons', 'num_unknown_neurons'])

# %% [markdown]
# ## Use Smoothed Data, Cal to Cal

# %%
for k in range(num_worms_train):
    worm = "worm" + str(k)
    if smoothed:
        calcium_data = dataset[worm]["smooth_calcium_data"]
        residual_calcium = dataset[worm]["residual_smooth_calcium"]
    else:
        calcium_data = dataset[worm]["calcium_data"]
        residual_calcium = dataset[worm]["residual_calcium"]

    cutdown = calcium_data.shape[0]
    train_size = int(0.5 * cutdown)
    print("split: 0.5")
    test_size = cutdown - train_size

    train_ca, test_ca = calcium_data.split(train_size, dim=0)
    train_res, test_res = residual_calcium.split(train_size, dim=0)

    train_loop_cal = []
    train_loop_res = []
    for i in range(0, train_ca.shape[0] - time_step):
        train_loop_res.append(np.array(train_res[i:i + time_step, :]))
        train_loop_cal.append(np.array(train_ca[i:i + time_step, :]))

    train_loop_cal = torch.tensor(np.array(train_loop_cal))
    train_loop_res = torch.tensor(np.array(train_loop_res))

    # print(train_loop_cal.shape, train_loop_res.shape)

    test_loop_cal = []
    test_loop_res = []
    for i in range(0, test_ca.shape[0] - time_step):
        test_loop_res.append(np.array(test_res[i:i + time_step, :]))
        test_loop_cal.append(np.array(test_ca[i:i + time_step, :]))

    test_loop_cal = torch.tensor(np.array(test_loop_cal))
    test_loop_res = torch.tensor(np.array(test_loop_res))

    train_loop_cal_target = torch.zeros_like(train_loop_cal)
    train_loop_cal_target[:-time_step] = train_loop_cal[time_step]

    test_loop_cal_target = torch.zeros_like(test_loop_cal)
    test_loop_cal_target[:-time_step] = test_loop_cal[time_step:]

    # print(test_loop_cal_target.shape)
    # plt.plot(test_loop_cal_target[:-time_step, 0, 0])
    # plt.plot(test_loop_cal[time_step:, 0, 0])
    # plt.show()
    #
    # exit(0)

    train_dataset = torch.utils.data.TensorDataset(train_loop_cal, train_loop_cal_target)
    test_dataset = torch.utils.data.TensorDataset(test_loop_cal, test_loop_cal_target)

    train_loader = torch.utils.data.DataLoader(
        dataset=train_dataset,
        batch_size=BATCH_SIZE,
        shuffle=False,
    )
    test_loader = torch.utils.data.DataLoader(
        dataset=test_dataset,
        batch_size=BATCH_SIZE,
        shuffle=False,
    )

    print("\n")
    print("--------worm " + "No. " + str(k) + "--------")
    # train_loader = worm_train[i]
    # test_loader = worm_test[i]
    train_base_loss_history = []
    train_pred_loss_history = []
    test_base_loss_history = []
    test_pred_loss_history = []
    for e in range(EPOCH):
        train_base_loss = 0
        train_pred_loss = 0
        test_base_loss = 0
        test_pred_loss = 0
        count = 0
        for X_train, Y_train in train_loader:
            mask_train = dataset[worm]["named_neurons_mask"]
            X_train, Y_train = torch.tensor(X_train, requires_grad=True), torch.tensor(Y_train, requires_grad=True)
            optimizer.zero_grad()
            # Baseline: loss if the model predicted the residual to be 0
            mask_train = mask_train.unsqueeze(0)
            mask_train = mask_train.repeat(Y_train.shape[0], Y_train.shape[1], 1)
            base = criterion(X_train * mask_train, Y_train * mask_train)
            Y_tr = model(X_train * mask_train)
            # Y_tr.retain_grad()
            # Y_tr.register_hook(lambda grad: grad * mask_train.float())
            loss = criterion(Y_tr * mask_train, Y_train * mask_train)
            loss.backward(retain_graph=True)
            optimizer.step()  # Update parameters based on gradients.
            train_base_loss += base.detach().item()
            train_pred_loss += loss.detach().item()
            count += 1
        train_base_loss_history.append(train_base_loss / count)
        train_pred_loss_history.append(train_pred_loss / count)
        count = 0
        for X_test, Y_test in test_loader:
            mask_test = dataset[worm]["named_neurons_mask"]
            X_test, Y_test = torch.tensor(X_test, requires_grad=True), torch.tensor(Y_test, requires_grad=True)
            optimizer.zero_grad()  # Clear gradients.
            mask_test = mask_test.repeat(Y_test.shape[1], 1)
            mask_test = mask_test.unsqueeze(0)
            mask_test = mask_test.repeat(Y_test.shape[0], 1, 1)
            # Baseline: loss if the model predicted the residual to be 0
            base = criterion(X_test * mask_test, Y_test * mask_test)
            # X_test = X_test.reshape((1, X_test.shape[0], X_test.shape[1])).transpose(1, 2)
            Y_pred = model(X_test * mask_test)  # .transpose(1, 2))  # Forward pass.
            loss = criterion(Y_pred * mask_test, Y_test * mask_test)
            test_base_loss += base.detach().item()
            test_pred_loss += loss.detach().item()
            count += 1
        # print("Count = ", count)
        # print("Test X_test shape = ", X_test.shape)
        # print("Test Y_test shape = ", Y_test.shape)
        test_base_loss_history.append(test_base_loss / count)
        test_pred_loss_history.append(test_pred_loss / count)

        print("epoch = {}, train_loss = {:.4f}, test_loss = {:.4f}".format(e, train_pred_loss_history[-1] -
                                                                           train_base_loss_history[-1],
                                                                           test_pred_loss_history[-1] -
                                                                           test_base_loss_history[-1]))

    delta_train = [train_pred_loss_history[i] - train_base_loss_history[i] for i in
                   range(len(train_base_loss_history))]
    delta_test = [test_pred_loss_history[i] - test_base_loss_history[i] for i in range(len(test_base_loss_history))]
    plt.plot(delta_train)
    plt.plot(delta_test)
    plt.legend(["train", "test"])
    plt.ylabel("Loss-Baseline")
    plt.xlabel("Epoch")
    plt.title("Worm " + str(k) + ", Epoch: " + str(EPOCH) + ", Loss: MSE")
    plt.show()

model_name = "model_LR" + str(LR) + "_E" + str(EPOCH) + ".pickle"
file = open(model_name, "wb")
torch.save(model.state_dict(), file)
# Out:
# split: 0.5
#
#
# --------worm No. 0--------
# /var/folders/nh/w4w39l451_gbdf_6q7r0pg8w0000gn/T/ipykernel_20619/1966237547.py:81: UserWarning: To copy construct from a tensor, it is recommended to use sourceTensor.clone().detach() or sourceTensor.clone().detach().requires_grad_(True), rather than torch.tensor(sourceTensor).
#   X_train, Y_train = torch.tensor(X_train, requires_grad=True), torch.tensor(Y_train, requires_grad=True)
# /var/folders/nh/w4w39l451_gbdf_6q7r0pg8w0000gn/T/ipykernel_20619/1966237547.py:101: UserWarning: To copy construct from a tensor, it is recommended to use sourceTensor.clone().detach() or sourceTensor.clone().detach().requires_grad_(True), rather than torch.tensor(sourceTensor).
#   X_test, Y_test = torch.tensor(X_test, requires_grad=True), torch.tensor(Y_test, requires_grad=True)
# epoch = 0, train_loss = -0.3063, test_loss = 0.3246
# epoch = 1, train_loss = -0.3064, test_loss = 0.3246
# epoch = 2, train_loss = -0.3066, test_loss = 0.3246
# epoch = 3, train_loss = -0.3067, test_loss = 0.3246
# epoch = 4, train_loss = -0.3068, test_loss = 0.3246
# epoch = 5, train_loss = -0.3069, test_loss = 0.3246
# epoch = 6, train_loss = -0.3071, test_loss = 0.3246
# epoch = 7, train_loss = -0.3072, test_loss = 0.3245
# epoch = 8, train_loss = -0.3073, test_loss = 0.3245
# epoch = 9, train_loss = -0.3075, test_loss = 0.3245
# epoch = 10, train_loss = -0.3076, test_loss = 0.3245
# epoch = 11, train_loss = -0.3077, test_loss = 0.3245
# epoch = 12, train_loss = -0.3078, test_loss = 0.3245
# epoch = 13, train_loss = -0.3080, test_loss = 0.3245
# epoch = 14, train_loss = -0.3081, test_loss = 0.3245
# epoch = 15, train_loss = -0.3082, test_loss = 0.3245
# epoch = 16, train_loss = -0.3083, test_loss = 0.3245
# epoch = 17, train_loss = -0.3085, test_loss = 0.3244
# epoch = 18, train_loss = -0.3086, test_loss = 0.3244
# epoch = 19, train_loss = -0.3087, test_loss = 0.3244
# epoch = 20, train_loss = -0.3088, test_loss = 0.3244
# epoch = 21, train_loss = -0.3089, test_loss = 0.3244
# epoch = 22, train_loss = -0.3091, test_loss = 0.3244
# epoch = 23, train_loss = -0.3092, test_loss = 0.3244
# epoch = 24, train_loss = -0.3093, test_loss = 0.3244
# epoch = 25, train_loss = -0.3094, test_loss = 0.3244
# epoch = 26, train_loss = -0.3095, test_loss = 0.3244
# epoch = 27, train_loss = -0.3096, test_loss = 0.3243
# epoch = 28, train_loss = -0.3098, test_loss = 0.3243
# epoch = 29, train_loss = -0.3099, test_loss = 0.3243
# epoch = 30, train_loss = -0.3100, test_loss = 0.3243
# epoch = 31, train_loss = -0.3101, test_loss = 0.3243
# epoch = 32, train_loss = -0.3102, test_loss = 0.3243
# epoch = 33, train_loss = -0.3103, test_loss = 0.3243
# epoch = 34, train_loss = -0.3104, test_loss = 0.3243
# epoch = 35, train_loss = -0.3105, test_loss = 0.3243
# epoch = 36, train_loss = -0.3106, test_loss = 0.3243
# epoch = 37, train_loss = -0.3108, test_loss = 0.3243
# epoch = 38, train_loss = -0.3109, test_loss = 0.3243
# epoch = 39, train_loss = -0.3110, test_loss = 0.3242
# epoch = 40, train_loss = -0.3111, test_loss = 0.3242
# epoch = 41, train_loss = -0.3112, test_loss = 0.3242
# epoch = 42, train_loss = -0.3113, test_loss = 0.3242
# epoch = 43, train_loss = -0.3114, test_loss = 0.3242
# epoch = 44, train_loss = -0.3115, test_loss = 0.3242
# epoch = 45, train_loss = -0.3116, test_loss = 0.3242
# epoch = 46, train_loss = -0.3117, test_loss = 0.3242
# epoch = 47, train_loss = -0.3118, test_loss = 0.3242
# epoch = 48, train_loss = -0.3119, test_loss = 0.3242
# epoch = 49, train_loss = -0.3120, test_loss = 0.3242
# epoch = 50, train_loss = -0.3121, test_loss = 0.3242
# epoch = 51, train_loss = -0.3122, test_loss = 0.3242
# epoch = 52, train_loss = -0.3123, test_loss = 0.3241
# epoch = 53, train_loss = -0.3124, test_loss = 0.3241
# epoch = 54, train_loss = -0.3125, test_loss = 0.3241
# epoch = 55, train_loss = -0.3126, test_loss = 0.3241
# epoch = 56, train_loss = -0.3127, test_loss = 0.3241
# epoch = 57, train_loss = -0.3128, test_loss = 0.3241
# epoch = 58, train_loss = -0.3129, test_loss = 0.3241
# epoch = 59, train_loss = -0.3130, test_loss = 0.3241
# epoch = 60, train_loss = -0.3131, test_loss = 0.3241
# epoch = 61, train_loss = -0.3132, test_loss = 0.3241
# epoch = 62, train_loss = -0.3133, test_loss = 0.3241
# epoch = 63, train_loss = -0.3134, test_loss = 0.3241
# epoch = 64, train_loss = -0.3135, test_loss = 0.3241
# epoch = 65, train_loss = -0.3136, test_loss = 0.3241
# epoch = 66, train_loss = -0.3137, test_loss = 0.3241
# epoch = 67, train_loss = -0.3138, test_loss = 0.3241
# epoch = 68, train_loss = -0.3139, test_loss = 0.3240
# epoch = 69, train_loss = -0.3140, test_loss = 0.3240
# epoch = 70, train_loss = -0.3141, test_loss = 0.3240
# epoch = 71, train_loss = -0.3141, test_loss = 0.3240
# epoch = 72, train_loss = -0.3142, test_loss = 0.3240
# epoch = 73, train_loss = -0.3143, test_loss = 0.3240
# epoch = 74, train_loss = -0.3144, test_loss = 0.3240
# epoch = 75, train_loss = -0.3145, test_loss = 0.3240
# epoch = 76, train_loss = -0.3146, test_loss = 0.3240
# epoch = 77, train_loss = -0.3147, test_loss = 0.3240
# epoch = 78, train_loss = -0.3148, test_loss = 0.3240
# epoch = 79, train_loss = -0.3149, test_loss = 0.3240
# epoch = 80, train_loss = -0.3150, test_loss = 0.3240
# epoch = 81, train_loss = -0.3151, test_loss = 0.3240
# epoch = 82, train_loss = -0.3151, test_loss = 0.3240
# epoch = 83, train_loss = -0.3152, test_loss = 0.3240
# epoch = 84, train_loss = -0.3153, test_loss = 0.3240
# epoch = 85, train_loss = -0.3154, test_loss = 0.3240
# epoch = 86, train_loss = -0.3155, test_loss = 0.3240
# epoch = 87, train_loss = -0.3156, test_loss = 0.3240
# epoch = 88, train_loss = -0.3157, test_loss = 0.3239
# epoch = 89, train_loss = -0.3157, test_loss = 0.3239
# epoch = 90, train_loss = -0.3158, test_loss = 0.3239
# epoch = 91, train_loss = -0.3159, test_loss = 0.3239
# epoch = 92, train_loss = -0.3160, test_loss = 0.3239
# epoch = 93, train_loss = -0.3161, test_loss = 0.3239
# epoch = 94, train_loss = -0.3162, test_loss = 0.3239
# epoch = 95, train_loss = -0.3163, test_loss = 0.3239
# epoch = 96, train_loss = -0.3163, test_loss = 0.3239
# epoch = 97, train_loss = -0.3164, test_loss = 0.3239
# epoch = 98, train_loss = -0.3165, test_loss = 0.3239
# epoch = 99, train_loss = -0.3166, test_loss = 0.3239
# epoch = 100, train_loss = -0.3167, test_loss = 0.3239
# epoch = 101, train_loss = -0.3167, test_loss = 0.3239
# epoch = 102, train_loss = -0.3168, test_loss = 0.3239
# epoch = 103, train_loss = -0.3169, test_loss = 0.3239
# epoch = 104, train_loss = -0.3170, test_loss = 0.3239
# epoch = 105, train_loss = -0.3171, test_loss = 0.3239
# epoch = 106, train_loss = -0.3172, test_loss = 0.3239
# epoch = 107, train_loss = -0.3172, test_loss = 0.3239
# epoch = 108, train_loss = -0.3173, test_loss = 0.3239
# epoch = 109, train_loss = -0.3174, test_loss = 0.3239
# epoch = 110, train_loss = -0.3175, test_loss = 0.3239
# epoch = 111, train_loss = -0.3175, test_loss = 0.3239
# epoch = 112, train_loss = -0.3176, test_loss = 0.3239
# epoch = 113, train_loss = -0.3177, test_loss = 0.3239
# epoch = 114, train_loss = -0.3178, test_loss = 0.3239
# epoch = 115, train_loss = -0.3179, test_loss = 0.3239
# epoch = 116, train_loss = -0.3179, test_loss = 0.3239
# epoch = 117, train_loss = -0.3180, test_loss = 0.3239
# epoch = 118, train_loss = -0.3181, test_loss = 0.3239
# epoch = 119, train_loss = -0.3182, test_loss = 0.3239
# epoch = 120, train_loss = -0.3182, test_loss = 0.3239
# epoch = 121, train_loss = -0.3183, test_loss = 0.3238
# epoch = 122, train_loss = -0.3184, test_loss = 0.3238
# epoch = 123, train_loss = -0.3185, test_loss = 0.3238
# epoch = 124, train_loss = -0.3185, test_loss = 0.3238
# epoch = 125, train_loss = -0.3186, test_loss = 0.3238
# epoch = 126, train_loss = -0.3187, test_loss = 0.3238
# epoch = 127, train_loss = -0.3188, test_loss = 0.3238
# epoch = 128, train_loss = -0.3188, test_loss = 0.3238
# epoch = 129, train_loss = -0.3189, test_loss = 0.3238
# epoch = 130, train_loss = -0.3190, test_loss = 0.3238
# epoch = 131, train_loss = -0.3191, test_loss = 0.3238
# epoch = 132, train_loss = -0.3191, test_loss = 0.3238
# epoch = 133, train_loss = -0.3192, test_loss = 0.3238
# epoch = 134, train_loss = -0.3193, test_loss = 0.3238
# epoch = 135, train_loss = -0.3193, test_loss = 0.3238
# epoch = 136, train_loss = -0.3194, test_loss = 0.3238
# epoch = 137, train_loss = -0.3195, test_loss = 0.3238
# epoch = 138, train_loss = -0.3196, test_loss = 0.3238
# epoch = 139, train_loss = -0.3196, test_loss = 0.3238
# epoch = 140, train_loss = -0.3197, test_loss = 0.3238
# epoch = 141, train_loss = -0.3198, test_loss = 0.3238
# epoch = 142, train_loss = -0.3198, test_loss = 0.3238
# epoch = 143, train_loss = -0.3199, test_loss = 0.3238
# epoch = 144, train_loss = -0.3200, test_loss = 0.3238
# epoch = 145, train_loss = -0.3200, test_loss = 0.3238
# epoch = 146, train_loss = -0.3201, test_loss = 0.3238
# epoch = 147, train_loss = -0.3202, test_loss = 0.3238
# epoch = 148, train_loss = -0.3203, test_loss = 0.3238
# epoch = 149, train_loss = -0.3203, test_loss = 0.3238
# epoch = 150, train_loss = -0.3204, test_loss = 0.3238
# epoch = 151, train_loss = -0.3205, test_loss = 0.3238
# epoch = 152, train_loss = -0.3205, test_loss = 0.3238
# epoch = 153, train_loss = -0.3206, test_loss = 0.3238
# epoch = 154, train_loss = -0.3207, test_loss = 0.3238
# epoch = 155, train_loss = -0.3207, test_loss = 0.3238
# epoch = 156, train_loss = -0.3208, test_loss = 0.3238
# epoch = 157, train_loss = -0.3209, test_loss = 0.3238
# epoch = 158, train_loss = -0.3209, test_loss = 0.3238
# epoch = 159, train_loss = -0.3210, test_loss = 0.3238
# epoch = 160, train_loss = -0.3211, test_loss = 0.3238
# epoch = 161, train_loss = -0.3211, test_loss = 0.3238
# epoch = 162, train_loss = -0.3212, test_loss = 0.3238
# epoch = 163, train_loss = -0.3212, test_loss = 0.3238
# epoch = 164, train_loss = -0.3213, test_loss = 0.3238
# epoch = 165, train_loss = -0.3214, test_loss = 0.3238
# epoch = 166, train_loss = -0.3214, test_loss = 0.3238
# epoch = 167, train_loss = -0.3215, test_loss = 0.3238
# epoch = 168, train_loss = -0.3216, test_loss = 0.3238
# epoch = 169, train_loss = -0.3216, test_loss = 0.3238
# epoch = 170, train_loss = -0.3217, test_loss = 0.3238
# epoch = 171, train_loss = -0.3218, test_loss = 0.3238
# epoch = 172, train_loss = -0.3218, test_loss = 0.3238
# epoch = 173, train_loss = -0.3219, test_loss = 0.3238
# epoch = 174, train_loss = -0.3219, test_loss = 0.3238
# epoch = 175, train_loss = -0.3220, test_loss = 0.3238
# epoch = 176, train_loss = -0.3221, test_loss = 0.3238
# epoch = 177, train_loss = -0.3221, test_loss = 0.3238
# epoch = 178, train_loss = -0.3222, test_loss = 0.3238
# epoch = 179, train_loss = -0.3223, test_loss = 0.3238
# epoch = 180, train_loss = -0.3223, test_loss = 0.3238
# epoch = 181, train_loss = -0.3224, test_loss = 0.3238
# epoch = 182, train_loss = -0.3224, test_loss = 0.3238
# epoch = 183, train_loss = -0.3225, test_loss = 0.3238
# epoch = 184, train_loss = -0.3226, test_loss = 0.3238
# epoch = 185, train_loss = -0.3226, test_loss = 0.3238
# epoch = 186, train_loss = -0.3227, test_loss = 0.3238
# epoch = 187, train_loss = -0.3227, test_loss = 0.3238
# epoch = 188, train_loss = -0.3228, test_loss = 0.3238
# epoch = 189, train_loss = -0.3229, test_loss = 0.3238
# epoch = 190, train_loss = -0.3229, test_loss = 0.3238
# epoch = 191, train_loss = -0.3230, test_loss = 0.3238
# epoch = 192, train_loss = -0.3230, test_loss = 0.3238
# epoch = 193, train_loss = -0.3231, test_loss = 0.3238
# epoch = 194, train_loss = -0.3231, test_loss = 0.3239
# epoch = 195, train_loss = -0.3232, test_loss = 0.3239
# epoch = 196, train_loss = -0.3233, test_loss = 0.3239
# epoch = 197, train_loss = -0.3233, test_loss = 0.3239
# epoch = 198, train_loss = -0.3234, test_loss = 0.3239
# epoch = 199, train_loss = -0.3234, test_loss = 0.3239
# epoch = 200, train_loss = -0.3235, test_loss = 0.3239
# epoch = 201, train_loss = -0.3235, test_loss = 0.3239
# epoch = 202, train_loss = -0.3236, test_loss = 0.3239
# epoch = 203, train_loss = -0.3237, test_loss = 0.3239
# epoch = 204, train_loss = -0.3237, test_loss = 0.3239
# epoch = 205, train_loss = -0.3238, test_loss = 0.3239
# epoch = 206, train_loss = -0.3238, test_loss = 0.3239
# epoch = 207, train_loss = -0.3239, test_loss = 0.3239
# epoch = 208, train_loss = -0.3239, test_loss = 0.3239
# epoch = 209, train_loss = -0.3240, test_loss = 0.3239
# epoch = 210, train_loss = -0.3240, test_loss = 0.3239
# epoch = 211, train_loss = -0.3241, test_loss = 0.3239
# epoch = 212, train_loss = -0.3241, test_loss = 0.3239
# epoch = 213, train_loss = -0.3242, test_loss = 0.3239
# epoch = 214, train_loss = -0.3243, test_loss = 0.3239
# epoch = 215, train_loss = -0.3243, test_loss = 0.3239
# epoch = 216, train_loss = -0.3244, test_loss = 0.3239
# epoch = 217, train_loss = -0.3244, test_loss = 0.3239
# epoch = 218, train_loss = -0.3245, test_loss = 0.3239
# epoch = 219, train_loss = -0.3245, test_loss = 0.3239
# epoch = 220, train_loss = -0.3246, test_loss = 0.3239
# epoch = 221, train_loss = -0.3246, test_loss = 0.3239
# epoch = 222, train_loss = -0.3247, test_loss = 0.3239
# epoch = 223, train_loss = -0.3247, test_loss = 0.3239
# epoch = 224, train_loss = -0.3248, test_loss = 0.3239
# epoch = 225, train_loss = -0.3248, test_loss = 0.3239
# epoch = 226, train_loss = -0.3249, test_loss = 0.3239
# epoch = 227, train_loss = -0.3249, test_loss = 0.3239
# epoch = 228, train_loss = -0.3250, test_loss = 0.3239
# epoch = 229, train_loss = -0.3250, test_loss = 0.3239
# epoch = 230, train_loss = -0.3251, test_loss = 0.3240
# epoch = 231, train_loss = -0.3251, test_loss = 0.3240
# epoch = 232, train_loss = -0.3252, test_loss = 0.3240
# epoch = 233, train_loss = -0.3252, test_loss = 0.3240
# epoch = 234, train_loss = -0.3253, test_loss = 0.3240
# epoch = 235, train_loss = -0.3253, test_loss = 0.3240
# epoch = 236, train_loss = -0.3254, test_loss = 0.3240
# epoch = 237, train_loss = -0.3254, test_loss = 0.3240
# epoch = 238, train_loss = -0.3255, test_loss = 0.3240
# epoch = 239, train_loss = -0.3255, test_loss = 0.3240
# epoch = 240, train_loss = -0.3256, test_loss = 0.3240
# epoch = 241, train_loss = -0.3256, test_loss = 0.3240
# epoch = 242, train_loss = -0.3257, test_loss = 0.3240
# epoch = 243, train_loss = -0.3257, test_loss = 0.3240
# epoch = 244, train_loss = -0.3258, test_loss = 0.3240
# epoch = 245, train_loss = -0.3258, test_loss = 0.3240
# epoch = 246, train_loss = -0.3259, test_loss = 0.3240
# epoch = 247, train_loss = -0.3259, test_loss = 0.3240
# epoch = 248, train_loss = -0.3260, test_loss = 0.3240
# epoch = 249, train_loss = -0.3260, test_loss = 0.3240
# epoch = 250, train_loss = -0.3260, test_loss = 0.3240
# epoch = 251, train_loss = -0.3261, test_loss = 0.3240
# epoch = 252, train_loss = -0.3261, test_loss = 0.3240
# epoch = 253, train_loss = -0.3262, test_loss = 0.3240
# epoch = 254, train_loss = -0.3262, test_loss = 0.3241
# epoch = 255, train_loss = -0.3263, test_loss = 0.3241
# epoch = 256, train_loss = -0.3263, test_loss = 0.3241
# epoch = 257, train_loss = -0.3264, test_loss = 0.3241
# epoch = 258, train_loss = -0.3264, test_loss = 0.3241
# epoch = 259, train_loss = -0.3265, test_loss = 0.3241
# epoch = 260, train_loss = -0.3265, test_loss = 0.3241
# epoch = 261, train_loss = -0.3265, test_loss = 0.3241
# epoch = 262, train_loss = -0.3266, test_loss = 0.3241
# epoch = 263, train_loss = -0.3266, test_loss = 0.3241
# epoch = 264, train_loss = -0.3267, test_loss = 0.3241
# epoch = 265, train_loss = -0.3267, test_loss = 0.3241
# epoch = 266, train_loss = -0.3268, test_loss = 0.3241
# epoch = 267, train_loss = -0.3268, test_loss = 0.3241
# epoch = 268, train_loss = -0.3268, test_loss = 0.3241
# epoch = 269, train_loss = -0.3269, test_loss = 0.3241
# epoch = 270, train_loss = -0.3269, test_loss = 0.3241
# epoch = 271, train_loss = -0.3270, test_loss = 0.3241
# epoch = 272, train_loss = -0.3270, test_loss = 0.3241
# epoch = 273, train_loss = -0.3271, test_loss = 0.3242
# epoch = 274, train_loss = -0.3271, test_loss = 0.3242
# epoch = 275, train_loss = -0.3271, test_loss = 0.3242
# epoch = 276, train_loss = -0.3272, test_loss = 0.3242
# epoch = 277, train_loss = -0.3272, test_loss = 0.3242
# epoch = 278, train_loss = -0.3273, test_loss = 0.3242
# epoch = 279, train_loss = -0.3273, test_loss = 0.3242
# epoch = 280, train_loss = -0.3273, test_loss = 0.3242
# epoch = 281, train_loss = -0.3274, test_loss = 0.3242
# epoch = 282, train_loss = -0.3274, test_loss = 0.3242
# epoch = 283, train_loss = -0.3275, test_loss = 0.3242
# epoch = 284, train_loss = -0.3275, test_loss = 0.3242
# epoch = 285, train_loss = -0.3275, test_loss = 0.3242
# epoch = 286, train_loss = -0.3276, test_loss = 0.3242
# epoch = 287, train_loss = -0.3276, test_loss = 0.3242
# epoch = 288, train_loss = -0.3277, test_loss = 0.3242
# epoch = 289, train_loss = -0.3277, test_loss = 0.3242
# epoch = 290, train_loss = -0.3277, test_loss = 0.3242
# epoch = 291, train_loss = -0.3278, test_loss = 0.3243
# epoch = 292, train_loss = -0.3278, test_loss = 0.3243
# epoch = 293, train_loss = -0.3279, test_loss = 0.3243
# epoch = 294, train_loss = -0.3279, test_loss = 0.3243
# epoch = 295, train_loss = -0.3279, test_loss = 0.3243
# epoch = 296, train_loss = -0.3280, test_loss = 0.3243
# epoch = 297, train_loss = -0.3280, test_loss = 0.3243
# epoch = 298, train_loss = -0.3281, test_loss = 0.3243
# epoch = 299, train_loss = -0.3281, test_loss = 0.3243
# epoch = 300, train_loss = -0.3281, test_loss = 0.3243
# epoch = 301, train_loss = -0.3282, test_loss = 0.3243
# epoch = 302, train_loss = -0.3282, test_loss = 0.3243
# epoch = 303, train_loss = -0.3282, test_loss = 0.3243
# epoch = 304, train_loss = -0.3283, test_loss = 0.3243
# epoch = 305, train_loss = -0.3283, test_loss = 0.3243
# epoch = 306, train_loss = -0.3283, test_loss = 0.3244
# epoch = 307, train_loss = -0.3284, test_loss = 0.3244
# epoch = 308, train_loss = -0.3284, test_loss = 0.3244
# epoch = 309, train_loss = -0.3285, test_loss = 0.3244
# epoch = 310, train_loss = -0.3285, test_loss = 0.3244
# epoch = 311, train_loss = -0.3285, test_loss = 0.3244
# epoch = 312, train_loss = -0.3286, test_loss = 0.3244
# epoch = 313, train_loss = -0.3286, test_loss = 0.3244
# epoch = 314, train_loss = -0.3286, test_loss = 0.3244
# epoch = 315, train_loss = -0.3287, test_loss = 0.3244
# epoch = 316, train_loss = -0.3287, test_loss = 0.3244
# epoch = 317, train_loss = -0.3287, test_loss = 0.3244
# epoch = 318, train_loss = -0.3288, test_loss = 0.3244
# epoch = 319, train_loss = -0.3288, test_loss = 0.3244
# epoch = 320, train_loss = -0.3288, test_loss = 0.3244
# epoch = 321, train_loss = -0.3289, test_loss = 0.3245
# epoch = 322, train_loss = -0.3289, test_loss = 0.3245
# epoch = 323, train_loss = -0.3289, test_loss = 0.3245
# epoch = 324, train_loss = -0.3290, test_loss = 0.3245
# epoch = 325, train_loss = -0.3290, test_loss = 0.3245
# epoch = 326, train_loss = -0.3290, test_loss = 0.3245
# epoch = 327, train_loss = -0.3291, test_loss = 0.3245
# epoch = 328, train_loss = -0.3291, test_loss = 0.3245
# epoch = 329, train_loss = -0.3291, test_loss = 0.3245
# epoch = 330, train_loss = -0.3292, test_loss = 0.3245
# epoch = 331, train_loss = -0.3292, test_loss = 0.3245
# epoch = 332, train_loss = -0.3292, test_loss = 0.3245
# epoch = 333, train_loss = -0.3293, test_loss = 0.3245
# epoch = 334, train_loss = -0.3293, test_loss = 0.3245
# epoch = 335, train_loss = -0.3293, test_loss = 0.3246
# epoch = 336, train_loss = -0.3293, test_loss = 0.3246
# epoch = 337, train_loss = -0.3294, test_loss = 0.3246
# epoch = 338, train_loss = -0.3294, test_loss = 0.3246
# epoch = 339, train_loss = -0.3294, test_loss = 0.3246
# epoch = 340, train_loss = -0.3295, test_loss = 0.3246
# epoch = 341, train_loss = -0.3295, test_loss = 0.3246
# epoch = 342, train_loss = -0.3295, test_loss = 0.3246
# epoch = 343, train_loss = -0.3296, test_loss = 0.3246
# epoch = 344, train_loss = -0.3296, test_loss = 0.3246
# epoch = 345, train_loss = -0.3296, test_loss = 0.3246
# epoch = 346, train_loss = -0.3297, test_loss = 0.3246
# epoch = 347, train_loss = -0.3297, test_loss = 0.3246
# epoch = 348, train_loss = -0.3297, test_loss = 0.3247
# epoch = 349, train_loss = -0.3297, test_loss = 0.3247
# epoch = 350, train_loss = -0.3298, test_loss = 0.3247
# epoch = 351, train_loss = -0.3298, test_loss = 0.3247
# epoch = 352, train_loss = -0.3298, test_loss = 0.3247
# epoch = 353, train_loss = -0.3299, test_loss = 0.3247
# epoch = 354, train_loss = -0.3299, test_loss = 0.3247
# epoch = 355, train_loss = -0.3299, test_loss = 0.3247
# epoch = 356, train_loss = -0.3299, test_loss = 0.3247
# epoch = 357, train_loss = -0.3300, test_loss = 0.3247
# epoch = 358, train_loss = -0.3300, test_loss = 0.3247
# epoch = 359, train_loss = -0.3300, test_loss = 0.3247
# epoch = 360, train_loss = -0.3300, test_loss = 0.3247
# epoch = 361, train_loss = -0.3301, test_loss = 0.3248
# epoch = 362, train_loss = -0.3301, test_loss = 0.3248
# epoch = 363, train_loss = -0.3301, test_loss = 0.3248
# epoch = 364, train_loss = -0.3302, test_loss = 0.3248
# epoch = 365, train_loss = -0.3302, test_loss = 0.3248
# epoch = 366, train_loss = -0.3302, test_loss = 0.3248
# epoch = 367, train_loss = -0.3302, test_loss = 0.3248
# epoch = 368, train_loss = -0.3303, test_loss = 0.3248
# epoch = 369, train_loss = -0.3303, test_loss = 0.3248
# epoch = 370, train_loss = -0.3303, test_loss = 0.3248
# epoch = 371, train_loss = -0.3303, test_loss = 0.3248
# epoch = 372, train_loss = -0.3304, test_loss = 0.3248
# epoch = 373, train_loss = -0.3304, test_loss = 0.3248
# epoch = 374, train_loss = -0.3304, test_loss = 0.3249
# epoch = 375, train_loss = -0.3304, test_loss = 0.3249
# epoch = 376, train_loss = -0.3305, test_loss = 0.3249
# epoch = 377, train_loss = -0.3305, test_loss = 0.3249
# epoch = 378, train_loss = -0.3305, test_loss = 0.3249
# epoch = 379, train_loss = -0.3305, test_loss = 0.3249
# epoch = 380, train_loss = -0.3306, test_loss = 0.3249
# epoch = 381, train_loss = -0.3306, test_loss = 0.3249
# epoch = 382, train_loss = -0.3306, test_loss = 0.3249
# epoch = 383, train_loss = -0.3306, test_loss = 0.3249
# epoch = 384, train_loss = -0.3307, test_loss = 0.3249
# epoch = 385, train_loss = -0.3307, test_loss = 0.3249
# epoch = 386, train_loss = -0.3307, test_loss = 0.3250
# epoch = 387, train_loss = -0.3307, test_loss = 0.3250
# epoch = 388, train_loss = -0.3308, test_loss = 0.3250
# epoch = 389, train_loss = -0.3308, test_loss = 0.3250
# epoch = 390, train_loss = -0.3308, test_loss = 0.3250
# epoch = 391, train_loss = -0.3308, test_loss = 0.3250
# epoch = 392, train_loss = -0.3308, test_loss = 0.3250
# epoch = 393, train_loss = -0.3309, test_loss = 0.3250
# epoch = 394, train_loss = -0.3309, test_loss = 0.3250
# epoch = 395, train_loss = -0.3309, test_loss = 0.3250
# epoch = 396, train_loss = -0.3309, test_loss = 0.3250
# epoch = 397, train_loss = -0.3310, test_loss = 0.3250
# epoch = 398, train_loss = -0.3310, test_loss = 0.3251
# epoch = 399, train_loss = -0.3310, test_loss = 0.3251
# epoch = 400, train_loss = -0.3310, test_loss = 0.3251
# epoch = 401, train_loss = -0.3310, test_loss = 0.3251
# epoch = 402, train_loss = -0.3311, test_loss = 0.3251
# epoch = 403, train_loss = -0.3311, test_loss = 0.3251
# epoch = 404, train_loss = -0.3311, test_loss = 0.3251
# epoch = 405, train_loss = -0.3311, test_loss = 0.3251
# epoch = 406, train_loss = -0.3312, test_loss = 0.3251
# epoch = 407, train_loss = -0.3312, test_loss = 0.3251
# epoch = 408, train_loss = -0.3312, test_loss = 0.3251
# epoch = 409, train_loss = -0.3312, test_loss = 0.3251
# epoch = 410, train_loss = -0.3312, test_loss = 0.3252
# epoch = 411, train_loss = -0.3313, test_loss = 0.3252
# epoch = 412, train_loss = -0.3313, test_loss = 0.3252
# epoch = 413, train_loss = -0.3313, test_loss = 0.3252
# epoch = 414, train_loss = -0.3313, test_loss = 0.3252
# epoch = 415, train_loss = -0.3313, test_loss = 0.3252
# epoch = 416, train_loss = -0.3314, test_loss = 0.3252
# epoch = 417, train_loss = -0.3314, test_loss = 0.3252
# epoch = 418, train_loss = -0.3314, test_loss = 0.3252
# epoch = 419, train_loss = -0.3314, test_loss = 0.3252
# epoch = 420, train_loss = -0.3314, test_loss = 0.3252
# epoch = 421, train_loss = -0.3315, test_loss = 0.3252
# epoch = 422, train_loss = -0.3315, test_loss = 0.3253
# epoch = 423, train_loss = -0.3315, test_loss = 0.3253
# epoch = 424, train_loss = -0.3315, test_loss = 0.3253
# epoch = 425, train_loss = -0.3315, test_loss = 0.3253
# epoch = 426, train_loss = -0.3316, test_loss = 0.3253
# epoch = 427, train_loss = -0.3316, test_loss = 0.3253
# epoch = 428, train_loss = -0.3316, test_loss = 0.3253
# epoch = 429, train_loss = -0.3316, test_loss = 0.3253
# epoch = 430, train_loss = -0.3316, test_loss = 0.3253
# epoch = 431, train_loss = -0.3316, test_loss = 0.3253
# epoch = 432, train_loss = -0.3317, test_loss = 0.3253
# epoch = 433, train_loss = -0.3317, test_loss = 0.3253
# epoch = 434, train_loss = -0.3317, test_loss = 0.3254
# epoch = 435, train_loss = -0.3317, test_loss = 0.3254
# epoch = 436, train_loss = -0.3317, test_loss = 0.3254
# epoch = 437, train_loss = -0.3318, test_loss = 0.3254
# epoch = 438, train_loss = -0.3318, test_loss = 0.3254
# epoch = 439, train_loss = -0.3318, test_loss = 0.3254
# epoch = 440, train_loss = -0.3318, test_loss = 0.3254
# epoch = 441, train_loss = -0.3318, test_loss = 0.3254
# epoch = 442, train_loss = -0.3318, test_loss = 0.3254
# epoch = 443, train_loss = -0.3319, test_loss = 0.3254
# epoch = 444, train_loss = -0.3319, test_loss = 0.3254
# epoch = 445, train_loss = -0.3319, test_loss = 0.3255
# epoch = 446, train_loss = -0.3319, test_loss = 0.3255
# epoch = 447, train_loss = -0.3319, test_loss = 0.3255
# epoch = 448, train_loss = -0.3319, test_loss = 0.3255
# epoch = 449, train_loss = -0.3320, test_loss = 0.3255
# epoch = 450, train_loss = -0.3320, test_loss = 0.3255
# epoch = 451, train_loss = -0.3320, test_loss = 0.3255
# epoch = 452, train_loss = -0.3320, test_loss = 0.3255
# epoch = 453, train_loss = -0.3320, test_loss = 0.3255
# epoch = 454, train_loss = -0.3320, test_loss = 0.3255
# epoch = 455, train_loss = -0.3321, test_loss = 0.3255
# epoch = 456, train_loss = -0.3321, test_loss = 0.3255
# epoch = 457, train_loss = -0.3321, test_loss = 0.3256
# epoch = 458, train_loss = -0.3321, test_loss = 0.3256
# epoch = 459, train_loss = -0.3321, test_loss = 0.3256
# epoch = 460, train_loss = -0.3321, test_loss = 0.3256
# epoch = 461, train_loss = -0.3321, test_loss = 0.3256
# epoch = 462, train_loss = -0.3322, test_loss = 0.3256
# epoch = 463, train_loss = -0.3322, test_loss = 0.3256
# epoch = 464, train_loss = -0.3322, test_loss = 0.3256
# epoch = 465, train_loss = -0.3322, test_loss = 0.3256
# epoch = 466, train_loss = -0.3322, test_loss = 0.3256
# epoch = 467, train_loss = -0.3322, test_loss = 0.3256
# epoch = 468, train_loss = -0.3322, test_loss = 0.3256
# epoch = 469, train_loss = -0.3323, test_loss = 0.3257
# epoch = 470, train_loss = -0.3323, test_loss = 0.3257
# epoch = 471, train_loss = -0.3323, test_loss = 0.3257
# epoch = 472, train_loss = -0.3323, test_loss = 0.3257
# epoch = 473, train_loss = -0.3323, test_loss = 0.3257
# epoch = 474, train_loss = -0.3323, test_loss = 0.3257
# epoch = 475, train_loss = -0.3323, test_loss = 0.3257
# epoch = 476, train_loss = -0.3324, test_loss = 0.3257
# epoch = 477, train_loss = -0.3324, test_loss = 0.3257
# epoch = 478, train_loss = -0.3324, test_loss = 0.3257
# epoch = 479, train_loss = -0.3324, test_loss = 0.3257
# epoch = 480, train_loss = -0.3324, test_loss = 0.3257
# epoch = 481, train_loss = -0.3324, test_loss = 0.3258
# epoch = 482, train_loss = -0.3324, test_loss = 0.3258
# epoch = 483, train_loss = -0.3325, test_loss = 0.3258
# epoch = 484, train_loss = -0.3325, test_loss = 0.3258
# epoch = 485, train_loss = -0.3325, test_loss = 0.3258
# epoch = 486, train_loss = -0.3325, test_loss = 0.3258
# epoch = 487, train_loss = -0.3325, test_loss = 0.3258
# epoch = 488, train_loss = -0.3325, test_loss = 0.3258
# epoch = 489, train_loss = -0.3325, test_loss = 0.3258
# epoch = 490, train_loss = -0.3325, test_loss = 0.3258
# epoch = 491, train_loss = -0.3326, test_loss = 0.3258
# epoch = 492, train_loss = -0.3326, test_loss = 0.3258
# epoch = 493, train_loss = -0.3326, test_loss = 0.3258
# epoch = 494, train_loss = -0.3326, test_loss = 0.3259
# epoch = 495, train_loss = -0.3326, test_loss = 0.3259
# epoch = 496, train_loss = -0.3326, test_loss = 0.3259
# epoch = 497, train_loss = -0.3326, test_loss = 0.3259
# epoch = 498, train_loss = -0.3326, test_loss = 0.3259
# epoch = 499, train_loss = -0.3327, test_loss = 0.3259

# %%
# if smoothed:
#     calcium_data = dataset[worm]["smooth_calcium_data"]
#     residual_calcium = dataset[worm]["residual_smooth_calcium"]
# else:
#     calcium_data = dataset[worm]["calcium_data"]
#     residual_calcium = dataset[worm]["residual_calcium"]

# file = open("model.pickle", "rb")
# model = torch.load(file)

from train._utils import *



dataset = get_dataset(OmegaConf.load("../../conf/dataset.yaml"))

model = get_model(OmegaConf.load("../../conf/model.yaml"))
model.load_state_dict((torch.load(model_name)))
model.eval()
calcium_data = dataset["worm0"]["calcium_data"]

mask_test = dataset["worm0"]["named_neurons_mask"]

# visualization of prediction
pred = []
target = []
X_test = []
Y_test = []


time_step = 20

num_neurons = 302
for i in range(time_step, calcium_data.shape[0] - time_step):
    X, Y = calcium_data[i - time_step:i, :num_neurons], calcium_data[i:i+time_step, :num_neurons]
    X_test.append(np.array(X))
    Y_test.append(np.array(Y))

X_test = torch.tensor(X_test)
Y_test = torch.tensor(Y_test)

print(X_test.shape, Y_test.shape, "---")

mask_test = mask_test.repeat(Y_test.shape[1], 1)
mask_test = mask_test.unsqueeze(0)
mask_test = mask_test.repeat(Y_test.shape[0], 1, 1)
# print(mask_test)
Y_test = Y_test * mask_test
Y_pred = model(X_test * mask_test)

Y_test = Y_test.detach().numpy()
Y_pred = Y_pred.detach().numpy()

print(dataset["worm0"]["num_named_neurons"], dataset["worm0"]["num_neurons"])

count = dataset["worm0"]["named_neurons_mask"].sum()
print(count)

# count = 0
# for i in range(0, Y_test.shape[2]):
#     # print(i+count)
#     if i+count >= dataset["worm0"]["named_neurons_mask"].shape[0]: break
#     if i >= Y_test.shape[2]: break
#     if dataset["worm0"]["named_neurons_mask"][i+count].item() is False:
#         Y_test = np.delete(Y_test, i, axis=2)
#         Y_pred = np.delete(Y_pred, i, axis=2)
#         i -= 1
#         count += 1


Y_test = torch.tensor(Y_test)
Y_pred = torch.tensor(Y_pred)

print(Y_pred.shape, Y_test.shape)

# %%
def draw_pic(Y_pred, Y_test, num, time):
    plt.plot(Y_test.detach().numpy()[:time, -1, num])
    plt.plot(Y_pred.detach().numpy()[:time, -1, num])
    plt.legend(["target", "pred"], loc="upper right")
    plt.title("Cal to Cal Prediction\n" + "Neuron No: " + str(num) + "   Time: 0-" + str(time))
    plt.show()



draw_pic(Y_pred, Y_test, 14, dataset["worm0"]["max_time"])
draw_pic(Y_pred, Y_test, 0, dataset["worm0"]["max_time"])
draw_pic(Y_pred, Y_test, 49, dataset["worm0"]["max_time"])
draw_pic(Y_pred, Y_test, 60, dataset["worm0"]["max_time"])
draw_pic(Y_pred, Y_test, 200, dataset["worm0"]["max_time"])
draw_pic(Y_pred, Y_test, 300, dataset["worm0"]["max_time"])

# %%
for i in range(6):
    # plt.plot(dataset["worm"+str(i)]["calcium_data"][:, 0])
    # plt.plot(dataset["worm"+str(i)]["calcium_data"][:, 60])
    print(dataset["worm"+str(i)]["named_neurons_mask"][0])
    print(dataset["worm"+str(i)]["named_neurons_mask"][60])
    plt.show()
