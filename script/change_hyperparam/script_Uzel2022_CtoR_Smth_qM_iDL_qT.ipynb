# %%
#!/usr/bin/env python
# encoding: utf-8

from train._utils import *

########################### Hyperparameters #########################
time_step = 10
BATCH_SIZE = 128
LR = 0.1
EPOCH = 100
num_worms_train = 6
smoothed = True
#####################################################################

model = get_model(OmegaConf.load("../../conf/model.yaml"))
optimizer = torch.optim.SGD(model.parameters(), lr=LR)
criterion = torch.nn.MSELoss(reduction="mean")

dataset = get_dataset(OmegaConf.load("../../conf/dataset.yaml"))

print(dataset["worm0"].keys())

plt.plot(dataset["worm0"]["smooth_calcium_data"][:, 1])
plt.plot(dataset["worm0"]["residual_smooth_calcium"][:, 1])
plt.show()
# Out:
# Model: NetworkLSTM(
#   (lstm): LSTM(302, 302, batch_first=True)
#   (linear): Linear(in_features=302, out_features=302, bias=True)
# )
#
# Chosen dataset(s): ['Uzel2022']
# Num. worms: 6
# Worm names: ['worm0', 'worm1', 'worm2', 'worm3', 'worm4', 'worm5']
#
#
# dict_keys(['dataset', 'worm', 'calcium_data', 'smooth_calcium_data', 'residual_calcium', 'residual_smooth_calcium', 'neuron_to_idx', 'idx_to_neuron', 'max_time', 'time_in_seconds', 'dt', 'num_neurons', 'num_named_neurons', 'num_unknown_neurons', 'named_neurons_mask', 'unknown_neurons_mask', 'neurons_mask', 'named_neuron_to_idx', 'idx_to_named_neuron', 'unknown_neuron_to_idx', 'idx_to_unknown_neuron', 'slot_to_named_neuron', 'named_neuron_to_slot', 'slot_to_unknown_neuron', 'unknown_neuron_to_slot', 'slot_to_neuron', 'neuron_to_slot'])

# %%
for k in range(num_worms_train):
    worm = "worm" + str(k)
    if smoothed:
        calcium_data = dataset[worm]["smooth_calcium_data"]
        residual_calcium = dataset[worm]["residual_smooth_calcium"]
    else:
        calcium_data = dataset[worm]["calcium_data"]
        residual_calcium = dataset[worm]["residual_calcium"]

    cutdown = calcium_data.shape[0]
    train_size = int(0.8 * cutdown)
    test_size = cutdown - train_size

    train_ca, test_ca = calcium_data.split(train_size, dim=0)
    train_res, test_res = residual_calcium.split(train_size, dim=0)

    train_loop_cal = []
    train_loop_res = []
    for i in range(0, train_ca.shape[0] - time_step):
        train_loop_res.append(np.array(train_res[i : i + time_step, :]))
        train_loop_cal.append(np.array(train_ca[i : i + time_step, :]))

    train_loop_cal = torch.tensor(np.array(train_loop_cal))
    train_loop_res = torch.tensor(np.array(train_loop_res))

    # print(train_loop_cal.shape, train_loop_res.shape)

    test_loop_cal = []
    test_loop_res = []
    for i in range(0, test_ca.shape[0] - time_step):
        test_loop_res.append(np.array(test_res[i : i + time_step, :]))
        test_loop_cal.append(np.array(test_ca[i : i + time_step, :]))

    test_loop_cal = torch.tensor(np.array(test_loop_cal))
    test_loop_res = torch.tensor(np.array(test_loop_res))

    train_dataset = torch.utils.data.TensorDataset(train_loop_cal, train_loop_res)
    test_dataset = torch.utils.data.TensorDataset(test_loop_cal, test_loop_res)

    train_loader = torch.utils.data.DataLoader(
        dataset=train_dataset,
        batch_size=BATCH_SIZE,
        shuffle=True,
    )
    test_loader = torch.utils.data.DataLoader(
        dataset=test_dataset,
        batch_size=BATCH_SIZE,
        shuffle=True,
    )

    print("\n")
    print("--------worm " + "No. " + str(k) + "--------")
    # train_loader = worm_train[i]
    # test_loader = worm_test[i]
    train_base_loss_history = []
    train_pred_loss_history = []
    test_base_loss_history = []
    test_pred_loss_history = []
    for e in range(EPOCH):
        train_base_loss = 0
        train_pred_loss = 0
        test_base_loss = 0
        test_pred_loss = 0
        count = 0
        for X_train, Y_train in train_loader:
            mask_train = dataset[worm]["named_neurons_mask"]
            X_train, Y_train = torch.tensor(X_train, requires_grad=True), torch.tensor(
                Y_train, requires_grad=True
            )
            optimizer.zero_grad()
            # Baseline: loss if the model predicted the residual to be 0
            mask_train = mask_train.unsqueeze(0)
            mask_train = mask_train.repeat(Y_train.shape[0], Y_train.shape[1], 1)
            base = criterion(
                torch.zeros_like(Y_train * mask_train), Y_train * mask_train
            )
            Y_tr = model(X_train)
            Y_tr.retain_grad()
            Y_tr.register_hook(lambda grad: grad * mask_train.double())
            loss = criterion(Y_tr * mask_train, Y_train * mask_train)
            loss.backward(retain_graph=True)
            optimizer.step()  # Update parameters based on gradients.
            train_base_loss += base.detach().item()
            train_pred_loss += loss.detach().item()
            count += 1
        train_base_loss_history.append(train_base_loss / count)
        train_pred_loss_history.append(train_pred_loss / count)
        count = 0
        for X_test, Y_test in test_loader:
            mask_test = dataset[worm]["named_neurons_mask"]
            X_test, Y_test = torch.tensor(X_test, requires_grad=True), torch.tensor(
                Y_test, requires_grad=True
            )
            optimizer.zero_grad()  # Clear gradients.
            mask_test = mask_test.repeat(Y_test.shape[1], 1)
            mask_test = mask_test.unsqueeze(0)
            mask_test = mask_test.repeat(Y_test.shape[0], 1, 1)
            # Baseline: loss if the model predicted the residual to be 0
            base = criterion(torch.zeros_like(Y_test * mask_test), Y_test * mask_test)
            # X_test = X_test.reshape((1, X_test.shape[0], X_test.shape[1])).transpose(1, 2)
            Y_pred = model(X_test)  # .transpose(1, 2))  # Forward pass.
            Y_pred = Y_pred  # .transpose(1, 2)
            loss = criterion(Y_pred * mask_test, Y_test * mask_test)
            test_base_loss += base.detach().item()
            test_pred_loss += loss.detach().item()
            count += 1
        test_base_loss_history.append(test_base_loss / count)
        test_pred_loss_history.append(test_pred_loss / count)

        print(
            "epoch = {}, train_loss = {:.4f}, test_loss = {:.4f}".format(
                e,
                train_pred_loss_history[-1] - train_base_loss_history[-1],
                test_pred_loss_history[-1] - test_base_loss_history[-1],
            )
        )

    delta_train = [
        train_pred_loss_history[i] - train_base_loss_history[i]
        for i in range(len(train_base_loss_history))
    ]
    delta_test = [
        test_pred_loss_history[i] - test_base_loss_history[i]
        for i in range(len(test_base_loss_history))
    ]
    plt.plot(delta_train)
    plt.plot(delta_test)
    plt.legend(["train", "test"])
    plt.ylabel("Loss-Baseline")
    plt.xlabel("Epoch")
    plt.title("Worm " + str(k) + ", Epoch: " + str(EPOCH) + ", Loss: MSE")
    plt.show()
# Out:
# --------worm No. 0--------
# /var/folders/nh/w4w39l451_gbdf_6q7r0pg8w0000gn/T/ipykernel_4882/2496376892.py:67: UserWarning: To copy construct from a tensor, it is recommended to use sourceTensor.clone().detach() or sourceTensor.clone().detach().requires_grad_(True), rather than torch.tensor(sourceTensor).
#   X_train, Y_train = torch.tensor(X_train, requires_grad=True), torch.tensor(Y_train, requires_grad=True)
# /var/folders/nh/w4w39l451_gbdf_6q7r0pg8w0000gn/T/ipykernel_4882/2496376892.py:91: UserWarning: To copy construct from a tensor, it is recommended to use sourceTensor.clone().detach() or sourceTensor.clone().detach().requires_grad_(True), rather than torch.tensor(sourceTensor).
#   X_test, Y_test = torch.tensor(X_test, requires_grad=True), torch.tensor(Y_test, requires_grad=True)
# epoch = 0, train_loss = 0.0007, test_loss = 0.0008
# epoch = 1, train_loss = 0.0007, test_loss = 0.0007
# epoch = 2, train_loss = 0.0006, test_loss = 0.0007
# epoch = 3, train_loss = 0.0006, test_loss = 0.0006
# epoch = 4, train_loss = 0.0005, test_loss = 0.0006
# epoch = 5, train_loss = 0.0005, test_loss = 0.0006
# epoch = 6, train_loss = 0.0005, test_loss = 0.0005
# epoch = 7, train_loss = 0.0004, test_loss = 0.0005
# epoch = 8, train_loss = 0.0004, test_loss = 0.0005
# epoch = 9, train_loss = 0.0004, test_loss = 0.0004
# epoch = 10, train_loss = 0.0004, test_loss = 0.0004
# epoch = 11, train_loss = 0.0004, test_loss = 0.0004
# epoch = 12, train_loss = 0.0003, test_loss = 0.0004
# epoch = 13, train_loss = 0.0003, test_loss = 0.0004
# epoch = 14, train_loss = 0.0003, test_loss = 0.0004
# epoch = 15, train_loss = 0.0003, test_loss = 0.0004
# epoch = 16, train_loss = 0.0003, test_loss = 0.0003
# epoch = 17, train_loss = 0.0003, test_loss = 0.0003
# epoch = 18, train_loss = 0.0003, test_loss = 0.0003
# epoch = 19, train_loss = 0.0003, test_loss = 0.0003
# epoch = 20, train_loss = 0.0003, test_loss = 0.0003
# epoch = 21, train_loss = 0.0002, test_loss = 0.0003
# epoch = 22, train_loss = 0.0002, test_loss = 0.0003
# epoch = 23, train_loss = 0.0002, test_loss = 0.0003
# epoch = 24, train_loss = 0.0002, test_loss = 0.0003
# epoch = 25, train_loss = 0.0002, test_loss = 0.0003
# epoch = 26, train_loss = 0.0002, test_loss = 0.0003
# epoch = 27, train_loss = 0.0002, test_loss = 0.0003
# epoch = 28, train_loss = 0.0002, test_loss = 0.0002
# epoch = 29, train_loss = 0.0002, test_loss = 0.0002
# epoch = 30, train_loss = 0.0002, test_loss = 0.0002
# epoch = 31, train_loss = 0.0002, test_loss = 0.0002
# epoch = 32, train_loss = 0.0002, test_loss = 0.0002
# epoch = 33, train_loss = 0.0002, test_loss = 0.0002
# epoch = 34, train_loss = 0.0002, test_loss = 0.0002
# epoch = 35, train_loss = 0.0002, test_loss = 0.0002
# epoch = 36, train_loss = 0.0002, test_loss = 0.0002
# epoch = 37, train_loss = 0.0002, test_loss = 0.0002
# epoch = 38, train_loss = 0.0002, test_loss = 0.0002
# epoch = 39, train_loss = 0.0002, test_loss = 0.0002
# epoch = 40, train_loss = 0.0002, test_loss = 0.0002
# epoch = 41, train_loss = 0.0002, test_loss = 0.0002
# epoch = 42, train_loss = 0.0002, test_loss = 0.0002
# epoch = 43, train_loss = 0.0002, test_loss = 0.0002
# epoch = 44, train_loss = 0.0002, test_loss = 0.0002
# epoch = 45, train_loss = 0.0002, test_loss = 0.0002
# epoch = 46, train_loss = 0.0002, test_loss = 0.0002
# epoch = 47, train_loss = 0.0002, test_loss = 0.0002
# epoch = 48, train_loss = 0.0002, test_loss = 0.0002
# epoch = 49, train_loss = 0.0001, test_loss = 0.0002
# epoch = 50, train_loss = 0.0001, test_loss = 0.0002
# epoch = 51, train_loss = 0.0001, test_loss = 0.0002
# epoch = 52, train_loss = 0.0001, test_loss = 0.0002
# epoch = 53, train_loss = 0.0001, test_loss = 0.0002
# epoch = 54, train_loss = 0.0001, test_loss = 0.0002
# epoch = 55, train_loss = 0.0001, test_loss = 0.0002
# epoch = 56, train_loss = 0.0001, test_loss = 0.0002
# epoch = 57, train_loss = 0.0001, test_loss = 0.0002
# epoch = 58, train_loss = 0.0001, test_loss = 0.0002
# epoch = 59, train_loss = 0.0001, test_loss = 0.0002
# epoch = 60, train_loss = 0.0001, test_loss = 0.0002
# epoch = 61, train_loss = 0.0001, test_loss = 0.0002
# epoch = 62, train_loss = 0.0001, test_loss = 0.0002
# epoch = 63, train_loss = 0.0001, test_loss = 0.0002
# epoch = 64, train_loss = 0.0001, test_loss = 0.0002
# epoch = 65, train_loss = 0.0001, test_loss = 0.0002
# epoch = 66, train_loss = 0.0001, test_loss = 0.0002
# epoch = 67, train_loss = 0.0001, test_loss = 0.0002
# epoch = 68, train_loss = 0.0001, test_loss = 0.0002
# epoch = 69, train_loss = 0.0001, test_loss = 0.0002
# epoch = 70, train_loss = 0.0001, test_loss = 0.0002
# epoch = 71, train_loss = 0.0001, test_loss = 0.0002
# epoch = 72, train_loss = 0.0001, test_loss = 0.0002
# epoch = 73, train_loss = 0.0001, test_loss = 0.0002
# epoch = 74, train_loss = 0.0001, test_loss = 0.0002
# epoch = 75, train_loss = 0.0001, test_loss = 0.0002
# epoch = 76, train_loss = 0.0001, test_loss = 0.0002
# epoch = 77, train_loss = 0.0001, test_loss = 0.0002
# epoch = 78, train_loss = 0.0001, test_loss = 0.0002
# epoch = 79, train_loss = 0.0001, test_loss = 0.0002
# epoch = 80, train_loss = 0.0001, test_loss = 0.0002
# epoch = 81, train_loss = 0.0001, test_loss = 0.0002
# epoch = 82, train_loss = 0.0001, test_loss = 0.0002
# epoch = 83, train_loss = 0.0001, test_loss = 0.0002
# epoch = 84, train_loss = 0.0001, test_loss = 0.0002
# epoch = 85, train_loss = 0.0001, test_loss = 0.0002
# epoch = 86, train_loss = 0.0001, test_loss = 0.0002
# epoch = 87, train_loss = 0.0001, test_loss = 0.0002
# epoch = 88, train_loss = 0.0001, test_loss = 0.0002
# epoch = 89, train_loss = 0.0001, test_loss = 0.0002
# epoch = 90, train_loss = 0.0001, test_loss = 0.0002
# epoch = 91, train_loss = 0.0001, test_loss = 0.0002
# epoch = 92, train_loss = 0.0001, test_loss = 0.0002
# epoch = 93, train_loss = 0.0001, test_loss = 0.0002
# epoch = 94, train_loss = 0.0001, test_loss = 0.0002
# epoch = 95, train_loss = 0.0001, test_loss = 0.0002
# epoch = 96, train_loss = 0.0001, test_loss = 0.0002
# epoch = 97, train_loss = 0.0001, test_loss = 0.0002
# epoch = 98, train_loss = 0.0001, test_loss = 0.0002
# epoch = 99, train_loss = 0.0001, test_loss = 0.0002
# --------worm No. 1--------
# epoch = 0, train_loss = 0.0005, test_loss = 0.0004
# epoch = 1, train_loss = 0.0004, test_loss = 0.0004
# epoch = 2, train_loss = 0.0004, test_loss = 0.0004
# epoch = 3, train_loss = 0.0004, test_loss = 0.0003
# epoch = 4, train_loss = 0.0003, test_loss = 0.0003
# epoch = 5, train_loss = 0.0003, test_loss = 0.0003
# epoch = 6, train_loss = 0.0003, test_loss = 0.0003
# epoch = 7, train_loss = 0.0003, test_loss = 0.0003
# epoch = 8, train_loss = 0.0003, test_loss = 0.0003
# epoch = 9, train_loss = 0.0003, test_loss = 0.0002
# epoch = 10, train_loss = 0.0002, test_loss = 0.0002
# epoch = 11, train_loss = 0.0002, test_loss = 0.0002
# epoch = 12, train_loss = 0.0002, test_loss = 0.0002
# epoch = 13, train_loss = 0.0002, test_loss = 0.0002
# epoch = 14, train_loss = 0.0002, test_loss = 0.0002
# epoch = 15, train_loss = 0.0002, test_loss = 0.0002
# epoch = 16, train_loss = 0.0002, test_loss = 0.0002
# epoch = 17, train_loss = 0.0002, test_loss = 0.0002
# epoch = 18, train_loss = 0.0002, test_loss = 0.0002
# epoch = 19, train_loss = 0.0002, test_loss = 0.0002
# epoch = 20, train_loss = 0.0002, test_loss = 0.0002
# epoch = 21, train_loss = 0.0002, test_loss = 0.0002
# epoch = 22, train_loss = 0.0002, test_loss = 0.0002
# epoch = 23, train_loss = 0.0002, test_loss = 0.0002
# epoch = 24, train_loss = 0.0002, test_loss = 0.0002
# epoch = 25, train_loss = 0.0001, test_loss = 0.0002
# epoch = 26, train_loss = 0.0001, test_loss = 0.0002
# epoch = 27, train_loss = 0.0001, test_loss = 0.0002
# epoch = 28, train_loss = 0.0001, test_loss = 0.0002
# epoch = 29, train_loss = 0.0001, test_loss = 0.0002
# epoch = 30, train_loss = 0.0001, test_loss = 0.0002
# epoch = 31, train_loss = 0.0001, test_loss = 0.0002
# epoch = 32, train_loss = 0.0001, test_loss = 0.0002
# epoch = 33, train_loss = 0.0001, test_loss = 0.0002
# epoch = 34, train_loss = 0.0001, test_loss = 0.0002
# epoch = 35, train_loss = 0.0001, test_loss = 0.0002
# epoch = 36, train_loss = 0.0001, test_loss = 0.0002
# epoch = 37, train_loss = 0.0001, test_loss = 0.0002
# epoch = 38, train_loss = 0.0001, test_loss = 0.0002
# epoch = 39, train_loss = 0.0001, test_loss = 0.0002
# epoch = 40, train_loss = 0.0001, test_loss = 0.0002
# epoch = 41, train_loss = 0.0001, test_loss = 0.0002
# epoch = 42, train_loss = 0.0001, test_loss = 0.0002
# epoch = 43, train_loss = 0.0001, test_loss = 0.0002
# epoch = 44, train_loss = 0.0001, test_loss = 0.0002
# epoch = 45, train_loss = 0.0001, test_loss = 0.0002
# epoch = 46, train_loss = 0.0001, test_loss = 0.0002
# epoch = 47, train_loss = 0.0001, test_loss = 0.0002
# epoch = 48, train_loss = 0.0001, test_loss = 0.0002
# epoch = 49, train_loss = 0.0001, test_loss = 0.0002
# epoch = 50, train_loss = 0.0001, test_loss = 0.0002
# epoch = 51, train_loss = 0.0001, test_loss = 0.0002
# epoch = 52, train_loss = 0.0001, test_loss = 0.0002
# epoch = 53, train_loss = 0.0001, test_loss = 0.0002
# epoch = 54, train_loss = 0.0001, test_loss = 0.0002
# epoch = 55, train_loss = 0.0001, test_loss = 0.0002
# epoch = 56, train_loss = 0.0001, test_loss = 0.0002
# epoch = 57, train_loss = 0.0001, test_loss = 0.0002
# epoch = 58, train_loss = 0.0001, test_loss = 0.0002
# epoch = 59, train_loss = 0.0001, test_loss = 0.0002
# epoch = 60, train_loss = 0.0001, test_loss = 0.0002
# epoch = 61, train_loss = 0.0001, test_loss = 0.0002
# epoch = 62, train_loss = 0.0001, test_loss = 0.0002
# epoch = 63, train_loss = 0.0001, test_loss = 0.0002
# epoch = 64, train_loss = 0.0001, test_loss = 0.0002
# epoch = 65, train_loss = 0.0001, test_loss = 0.0002
# epoch = 66, train_loss = 0.0001, test_loss = 0.0002
# epoch = 67, train_loss = 0.0001, test_loss = 0.0002
# epoch = 68, train_loss = 0.0001, test_loss = 0.0002
# epoch = 69, train_loss = 0.0001, test_loss = 0.0002
# epoch = 70, train_loss = 0.0001, test_loss = 0.0002
# epoch = 71, train_loss = 0.0001, test_loss = 0.0002
# epoch = 72, train_loss = 0.0001, test_loss = 0.0002
# epoch = 73, train_loss = 0.0001, test_loss = 0.0002
# epoch = 74, train_loss = 0.0001, test_loss = 0.0002
# epoch = 75, train_loss = 0.0001, test_loss = 0.0002
# epoch = 76, train_loss = 0.0001, test_loss = 0.0002
# epoch = 77, train_loss = 0.0001, test_loss = 0.0002
# epoch = 78, train_loss = 0.0001, test_loss = 0.0002
# epoch = 79, train_loss = 0.0001, test_loss = 0.0002
# epoch = 80, train_loss = 0.0001, test_loss = 0.0002
# epoch = 81, train_loss = 0.0001, test_loss = 0.0002
# epoch = 82, train_loss = 0.0001, test_loss = 0.0002
# epoch = 83, train_loss = 0.0001, test_loss = 0.0002
# epoch = 84, train_loss = 0.0001, test_loss = 0.0002
# epoch = 85, train_loss = 0.0001, test_loss = 0.0002
# epoch = 86, train_loss = 0.0001, test_loss = 0.0002
# epoch = 87, train_loss = 0.0001, test_loss = 0.0002
# epoch = 88, train_loss = 0.0001, test_loss = 0.0002
# epoch = 89, train_loss = 0.0001, test_loss = 0.0002
# epoch = 90, train_loss = 0.0001, test_loss = 0.0002
# epoch = 91, train_loss = 0.0001, test_loss = 0.0001
# epoch = 92, train_loss = 0.0001, test_loss = 0.0001
# epoch = 93, train_loss = 0.0001, test_loss = 0.0001
# epoch = 94, train_loss = 0.0001, test_loss = 0.0001
# epoch = 95, train_loss = 0.0001, test_loss = 0.0001
# epoch = 96, train_loss = 0.0001, test_loss = 0.0001
# epoch = 97, train_loss = 0.0001, test_loss = 0.0001
# epoch = 98, train_loss = 0.0001, test_loss = 0.0001
# epoch = 99, train_loss = 0.0001, test_loss = 0.0001
# --------worm No. 2--------
# epoch = 0, train_loss = 0.0003, test_loss = 0.0004
# epoch = 1, train_loss = 0.0003, test_loss = 0.0003
# epoch = 2, train_loss = 0.0002, test_loss = 0.0003
# epoch = 3, train_loss = 0.0002, test_loss = 0.0003
# epoch = 4, train_loss = 0.0002, test_loss = 0.0003
# epoch = 5, train_loss = 0.0002, test_loss = 0.0003
# epoch = 6, train_loss = 0.0002, test_loss = 0.0003
# epoch = 7, train_loss = 0.0002, test_loss = 0.0003
# epoch = 8, train_loss = 0.0002, test_loss = 0.0003
# epoch = 9, train_loss = 0.0002, test_loss = 0.0003
# epoch = 10, train_loss = 0.0002, test_loss = 0.0002
# epoch = 11, train_loss = 0.0002, test_loss = 0.0002
# epoch = 12, train_loss = 0.0002, test_loss = 0.0002
# epoch = 13, train_loss = 0.0002, test_loss = 0.0002
# epoch = 14, train_loss = 0.0002, test_loss = 0.0002
# epoch = 15, train_loss = 0.0002, test_loss = 0.0002
# epoch = 16, train_loss = 0.0002, test_loss = 0.0002
# epoch = 17, train_loss = 0.0001, test_loss = 0.0002
# epoch = 18, train_loss = 0.0001, test_loss = 0.0002
# epoch = 19, train_loss = 0.0001, test_loss = 0.0002
# epoch = 20, train_loss = 0.0001, test_loss = 0.0002
# epoch = 21, train_loss = 0.0001, test_loss = 0.0002
# epoch = 22, train_loss = 0.0001, test_loss = 0.0002
# epoch = 23, train_loss = 0.0001, test_loss = 0.0002
# epoch = 24, train_loss = 0.0001, test_loss = 0.0002
# epoch = 25, train_loss = 0.0001, test_loss = 0.0002
# epoch = 26, train_loss = 0.0001, test_loss = 0.0002
# epoch = 27, train_loss = 0.0001, test_loss = 0.0002
# epoch = 28, train_loss = 0.0001, test_loss = 0.0002
# epoch = 29, train_loss = 0.0001, test_loss = 0.0002
# epoch = 30, train_loss = 0.0001, test_loss = 0.0002
# epoch = 31, train_loss = 0.0001, test_loss = 0.0002
# epoch = 32, train_loss = 0.0001, test_loss = 0.0002
# epoch = 33, train_loss = 0.0001, test_loss = 0.0002
# epoch = 34, train_loss = 0.0001, test_loss = 0.0002
# epoch = 35, train_loss = 0.0001, test_loss = 0.0002
# epoch = 36, train_loss = 0.0001, test_loss = 0.0002
# epoch = 37, train_loss = 0.0001, test_loss = 0.0002
# epoch = 38, train_loss = 0.0001, test_loss = 0.0002
# epoch = 39, train_loss = 0.0001, test_loss = 0.0002
# epoch = 40, train_loss = 0.0001, test_loss = 0.0002
# epoch = 41, train_loss = 0.0001, test_loss = 0.0002
# epoch = 42, train_loss = 0.0001, test_loss = 0.0002
# epoch = 43, train_loss = 0.0001, test_loss = 0.0002
# epoch = 44, train_loss = 0.0001, test_loss = 0.0002
# epoch = 45, train_loss = 0.0001, test_loss = 0.0002
# epoch = 46, train_loss = 0.0001, test_loss = 0.0002
# epoch = 47, train_loss = 0.0001, test_loss = 0.0002
# epoch = 48, train_loss = 0.0001, test_loss = 0.0002
# epoch = 49, train_loss = 0.0001, test_loss = 0.0002
# epoch = 50, train_loss = 0.0001, test_loss = 0.0001
# epoch = 51, train_loss = 0.0001, test_loss = 0.0001
# epoch = 52, train_loss = 0.0001, test_loss = 0.0001
# epoch = 53, train_loss = 0.0001, test_loss = 0.0001
# epoch = 54, train_loss = 0.0001, test_loss = 0.0001
# epoch = 55, train_loss = 0.0001, test_loss = 0.0001
# epoch = 56, train_loss = 0.0001, test_loss = 0.0001
# epoch = 57, train_loss = 0.0001, test_loss = 0.0001
# epoch = 58, train_loss = 0.0001, test_loss = 0.0001
# epoch = 59, train_loss = 0.0001, test_loss = 0.0001
# epoch = 60, train_loss = 0.0001, test_loss = 0.0001
# epoch = 61, train_loss = 0.0001, test_loss = 0.0001
# epoch = 62, train_loss = 0.0001, test_loss = 0.0001
# epoch = 63, train_loss = 0.0001, test_loss = 0.0001
# epoch = 64, train_loss = 0.0001, test_loss = 0.0001
# epoch = 65, train_loss = 0.0001, test_loss = 0.0001
# epoch = 66, train_loss = 0.0001, test_loss = 0.0001
# epoch = 67, train_loss = 0.0001, test_loss = 0.0001
# epoch = 68, train_loss = 0.0001, test_loss = 0.0001
# epoch = 69, train_loss = 0.0001, test_loss = 0.0001
# epoch = 70, train_loss = 0.0001, test_loss = 0.0001
# epoch = 71, train_loss = 0.0001, test_loss = 0.0001
# epoch = 72, train_loss = 0.0001, test_loss = 0.0001
# epoch = 73, train_loss = 0.0001, test_loss = 0.0001
# epoch = 74, train_loss = 0.0001, test_loss = 0.0001
# epoch = 75, train_loss = 0.0001, test_loss = 0.0001
# epoch = 76, train_loss = 0.0001, test_loss = 0.0001
# epoch = 77, train_loss = 0.0001, test_loss = 0.0001
# epoch = 78, train_loss = 0.0001, test_loss = 0.0001
# epoch = 79, train_loss = 0.0001, test_loss = 0.0001
# epoch = 80, train_loss = 0.0001, test_loss = 0.0001
# epoch = 81, train_loss = 0.0001, test_loss = 0.0001
# epoch = 82, train_loss = 0.0001, test_loss = 0.0001
# epoch = 83, train_loss = 0.0001, test_loss = 0.0001
# epoch = 84, train_loss = 0.0001, test_loss = 0.0001
# epoch = 85, train_loss = 0.0001, test_loss = 0.0001
# epoch = 86, train_loss = 0.0001, test_loss = 0.0001
# epoch = 87, train_loss = 0.0001, test_loss = 0.0001
# epoch = 88, train_loss = 0.0001, test_loss = 0.0001
# epoch = 89, train_loss = 0.0001, test_loss = 0.0001
# epoch = 90, train_loss = 0.0001, test_loss = 0.0001
# epoch = 91, train_loss = 0.0001, test_loss = 0.0001
# epoch = 92, train_loss = 0.0001, test_loss = 0.0001
# epoch = 93, train_loss = 0.0001, test_loss = 0.0001
# epoch = 94, train_loss = 0.0001, test_loss = 0.0001
# epoch = 95, train_loss = 0.0001, test_loss = 0.0001
# epoch = 96, train_loss = 0.0001, test_loss = 0.0001
# epoch = 97, train_loss = 0.0001, test_loss = 0.0001
# epoch = 98, train_loss = 0.0001, test_loss = 0.0001
# epoch = 99, train_loss = 0.0001, test_loss = 0.0001
# --------worm No. 3--------
# epoch = 0, train_loss = 0.0002, test_loss = 0.0002
# epoch = 1, train_loss = 0.0002, test_loss = 0.0002
# epoch = 2, train_loss = 0.0002, test_loss = 0.0002
# epoch = 3, train_loss = 0.0001, test_loss = 0.0002
# epoch = 4, train_loss = 0.0001, test_loss = 0.0001
# epoch = 5, train_loss = 0.0001, test_loss = 0.0001
# epoch = 6, train_loss = 0.0001, test_loss = 0.0001
# epoch = 7, train_loss = 0.0001, test_loss = 0.0001
# epoch = 8, train_loss = 0.0001, test_loss = 0.0001
# epoch = 9, train_loss = 0.0001, test_loss = 0.0001
# epoch = 10, train_loss = 0.0001, test_loss = 0.0001
# epoch = 11, train_loss = 0.0001, test_loss = 0.0001
# epoch = 12, train_loss = 0.0001, test_loss = 0.0001
# epoch = 13, train_loss = 0.0001, test_loss = 0.0001
# epoch = 14, train_loss = 0.0001, test_loss = 0.0001
# epoch = 15, train_loss = 0.0001, test_loss = 0.0001
# epoch = 16, train_loss = 0.0001, test_loss = 0.0001
# epoch = 17, train_loss = 0.0001, test_loss = 0.0001
# epoch = 18, train_loss = 0.0001, test_loss = 0.0001
# epoch = 19, train_loss = 0.0001, test_loss = 0.0001
# epoch = 20, train_loss = 0.0001, test_loss = 0.0001
# epoch = 21, train_loss = 0.0001, test_loss = 0.0001
# epoch = 22, train_loss = 0.0001, test_loss = 0.0001
# epoch = 23, train_loss = 0.0001, test_loss = 0.0001
# epoch = 24, train_loss = 0.0001, test_loss = 0.0001
# epoch = 25, train_loss = 0.0001, test_loss = 0.0001
# epoch = 26, train_loss = 0.0001, test_loss = 0.0001
# epoch = 27, train_loss = 0.0001, test_loss = 0.0001
# epoch = 28, train_loss = 0.0001, test_loss = 0.0001
# epoch = 29, train_loss = 0.0001, test_loss = 0.0001
# epoch = 30, train_loss = 0.0001, test_loss = 0.0001
# epoch = 31, train_loss = 0.0001, test_loss = 0.0001
# epoch = 32, train_loss = 0.0001, test_loss = 0.0001
# epoch = 33, train_loss = 0.0001, test_loss = 0.0001
# epoch = 34, train_loss = 0.0001, test_loss = 0.0001
# epoch = 35, train_loss = 0.0001, test_loss = 0.0001
# epoch = 36, train_loss = 0.0001, test_loss = 0.0001
# epoch = 37, train_loss = 0.0001, test_loss = 0.0001
# epoch = 38, train_loss = 0.0001, test_loss = 0.0001
# epoch = 39, train_loss = 0.0001, test_loss = 0.0001
# epoch = 40, train_loss = 0.0001, test_loss = 0.0001
# epoch = 41, train_loss = 0.0001, test_loss = 0.0001
# epoch = 42, train_loss = 0.0001, test_loss = 0.0001
# epoch = 43, train_loss = 0.0001, test_loss = 0.0001
# epoch = 44, train_loss = 0.0001, test_loss = 0.0001
# epoch = 45, train_loss = 0.0001, test_loss = 0.0001
# epoch = 46, train_loss = 0.0001, test_loss = 0.0001
# epoch = 47, train_loss = 0.0001, test_loss = 0.0001
# epoch = 48, train_loss = 0.0001, test_loss = 0.0001
# epoch = 49, train_loss = 0.0001, test_loss = 0.0001
# epoch = 50, train_loss = 0.0001, test_loss = 0.0001
# epoch = 51, train_loss = 0.0001, test_loss = 0.0001
# epoch = 52, train_loss = 0.0001, test_loss = 0.0001
# epoch = 53, train_loss = 0.0001, test_loss = 0.0001
# epoch = 54, train_loss = 0.0001, test_loss = 0.0001
# epoch = 55, train_loss = 0.0001, test_loss = 0.0001
# epoch = 56, train_loss = 0.0001, test_loss = 0.0001
# epoch = 57, train_loss = 0.0001, test_loss = 0.0001
# epoch = 58, train_loss = 0.0001, test_loss = 0.0001
# epoch = 59, train_loss = 0.0001, test_loss = 0.0001
# epoch = 60, train_loss = 0.0001, test_loss = 0.0001
# epoch = 61, train_loss = 0.0001, test_loss = 0.0001
# epoch = 62, train_loss = 0.0001, test_loss = 0.0001
# epoch = 63, train_loss = 0.0001, test_loss = 0.0001
# epoch = 64, train_loss = 0.0001, test_loss = 0.0001
# epoch = 65, train_loss = 0.0001, test_loss = 0.0001
# epoch = 66, train_loss = 0.0001, test_loss = 0.0001
# epoch = 67, train_loss = 0.0001, test_loss = 0.0001
# epoch = 68, train_loss = 0.0001, test_loss = 0.0001
# epoch = 69, train_loss = 0.0001, test_loss = 0.0001
# epoch = 70, train_loss = 0.0001, test_loss = 0.0001
# epoch = 71, train_loss = 0.0001, test_loss = 0.0001
# epoch = 72, train_loss = 0.0001, test_loss = 0.0001
# epoch = 73, train_loss = 0.0001, test_loss = 0.0001
# epoch = 74, train_loss = 0.0001, test_loss = 0.0001
# epoch = 75, train_loss = 0.0001, test_loss = 0.0001
# epoch = 76, train_loss = 0.0001, test_loss = 0.0001
# epoch = 77, train_loss = 0.0001, test_loss = 0.0001
# epoch = 78, train_loss = 0.0001, test_loss = 0.0001
# epoch = 79, train_loss = 0.0001, test_loss = 0.0001
# epoch = 80, train_loss = 0.0001, test_loss = 0.0001
# epoch = 81, train_loss = 0.0001, test_loss = 0.0001
# epoch = 82, train_loss = 0.0001, test_loss = 0.0001
# epoch = 83, train_loss = 0.0001, test_loss = 0.0001
# epoch = 84, train_loss = 0.0001, test_loss = 0.0001
# epoch = 85, train_loss = 0.0001, test_loss = 0.0001
# epoch = 86, train_loss = 0.0001, test_loss = 0.0001
# epoch = 87, train_loss = 0.0001, test_loss = 0.0001
# epoch = 88, train_loss = 0.0001, test_loss = 0.0001
# epoch = 89, train_loss = 0.0001, test_loss = 0.0001
# epoch = 90, train_loss = 0.0001, test_loss = 0.0001
# epoch = 91, train_loss = 0.0001, test_loss = 0.0001
# epoch = 92, train_loss = 0.0001, test_loss = 0.0001
# epoch = 93, train_loss = 0.0001, test_loss = 0.0001
# epoch = 94, train_loss = 0.0001, test_loss = 0.0001
# epoch = 95, train_loss = 0.0001, test_loss = 0.0001
# epoch = 96, train_loss = 0.0001, test_loss = 0.0001
# epoch = 97, train_loss = 0.0000, test_loss = 0.0001
# epoch = 98, train_loss = 0.0000, test_loss = 0.0001
# epoch = 99, train_loss = 0.0000, test_loss = 0.0001
# --------worm No. 4--------
# epoch = 0, train_loss = 0.0002, test_loss = 0.0003
# epoch = 1, train_loss = 0.0002, test_loss = 0.0003
# epoch = 2, train_loss = 0.0002, test_loss = 0.0003
# epoch = 3, train_loss = 0.0002, test_loss = 0.0003
# epoch = 4, train_loss = 0.0002, test_loss = 0.0002
# epoch = 5, train_loss = 0.0002, test_loss = 0.0002
# epoch = 6, train_loss = 0.0002, test_loss = 0.0002
# epoch = 7, train_loss = 0.0002, test_loss = 0.0002
# epoch = 8, train_loss = 0.0002, test_loss = 0.0002
# epoch = 9, train_loss = 0.0002, test_loss = 0.0002
# epoch = 10, train_loss = 0.0002, test_loss = 0.0002
# epoch = 11, train_loss = 0.0002, test_loss = 0.0002
# epoch = 12, train_loss = 0.0002, test_loss = 0.0002
# epoch = 13, train_loss = 0.0002, test_loss = 0.0002
# epoch = 14, train_loss = 0.0002, test_loss = 0.0002
# epoch = 15, train_loss = 0.0001, test_loss = 0.0002
# epoch = 16, train_loss = 0.0001, test_loss = 0.0002
# epoch = 17, train_loss = 0.0001, test_loss = 0.0002
# epoch = 18, train_loss = 0.0001, test_loss = 0.0002
# epoch = 19, train_loss = 0.0001, test_loss = 0.0002
# epoch = 20, train_loss = 0.0001, test_loss = 0.0002
# epoch = 21, train_loss = 0.0001, test_loss = 0.0002
# epoch = 22, train_loss = 0.0001, test_loss = 0.0002
# epoch = 23, train_loss = 0.0001, test_loss = 0.0002
# epoch = 24, train_loss = 0.0001, test_loss = 0.0002
# epoch = 25, train_loss = 0.0001, test_loss = 0.0002
# epoch = 26, train_loss = 0.0001, test_loss = 0.0002
# epoch = 27, train_loss = 0.0001, test_loss = 0.0002
# epoch = 28, train_loss = 0.0001, test_loss = 0.0002
# epoch = 29, train_loss = 0.0001, test_loss = 0.0002
# epoch = 30, train_loss = 0.0001, test_loss = 0.0002
# epoch = 31, train_loss = 0.0001, test_loss = 0.0002
# epoch = 32, train_loss = 0.0001, test_loss = 0.0002
# epoch = 33, train_loss = 0.0001, test_loss = 0.0002
# epoch = 34, train_loss = 0.0001, test_loss = 0.0002
# epoch = 35, train_loss = 0.0001, test_loss = 0.0002
# epoch = 36, train_loss = 0.0001, test_loss = 0.0002
# epoch = 37, train_loss = 0.0001, test_loss = 0.0002
# epoch = 38, train_loss = 0.0001, test_loss = 0.0002
# epoch = 39, train_loss = 0.0001, test_loss = 0.0002
# epoch = 40, train_loss = 0.0001, test_loss = 0.0002
# epoch = 41, train_loss = 0.0001, test_loss = 0.0002
# epoch = 42, train_loss = 0.0001, test_loss = 0.0002
# epoch = 43, train_loss = 0.0001, test_loss = 0.0002
# epoch = 44, train_loss = 0.0001, test_loss = 0.0002
# epoch = 45, train_loss = 0.0001, test_loss = 0.0002
# epoch = 46, train_loss = 0.0001, test_loss = 0.0002
# epoch = 47, train_loss = 0.0001, test_loss = 0.0002
# epoch = 48, train_loss = 0.0001, test_loss = 0.0002
# epoch = 49, train_loss = 0.0001, test_loss = 0.0002
# epoch = 50, train_loss = 0.0001, test_loss = 0.0002
# epoch = 51, train_loss = 0.0001, test_loss = 0.0002
# epoch = 52, train_loss = 0.0001, test_loss = 0.0002
# epoch = 53, train_loss = 0.0001, test_loss = 0.0002
# epoch = 54, train_loss = 0.0001, test_loss = 0.0002
# epoch = 55, train_loss = 0.0001, test_loss = 0.0002
# epoch = 56, train_loss = 0.0001, test_loss = 0.0002
# epoch = 57, train_loss = 0.0001, test_loss = 0.0002
# epoch = 58, train_loss = 0.0001, test_loss = 0.0002
# epoch = 59, train_loss = 0.0001, test_loss = 0.0002
# epoch = 60, train_loss = 0.0001, test_loss = 0.0001
# epoch = 61, train_loss = 0.0001, test_loss = 0.0002
# epoch = 62, train_loss = 0.0001, test_loss = 0.0002
# epoch = 63, train_loss = 0.0001, test_loss = 0.0002
# epoch = 64, train_loss = 0.0001, test_loss = 0.0001
# epoch = 65, train_loss = 0.0001, test_loss = 0.0002
# epoch = 66, train_loss = 0.0001, test_loss = 0.0002
# epoch = 67, train_loss = 0.0001, test_loss = 0.0001
# epoch = 68, train_loss = 0.0001, test_loss = 0.0001
# epoch = 69, train_loss = 0.0001, test_loss = 0.0001
# epoch = 70, train_loss = 0.0001, test_loss = 0.0001
# epoch = 71, train_loss = 0.0001, test_loss = 0.0001
# epoch = 72, train_loss = 0.0001, test_loss = 0.0001
# epoch = 73, train_loss = 0.0001, test_loss = 0.0001
# epoch = 74, train_loss = 0.0001, test_loss = 0.0001
# epoch = 75, train_loss = 0.0001, test_loss = 0.0001
# epoch = 76, train_loss = 0.0001, test_loss = 0.0001
# epoch = 77, train_loss = 0.0001, test_loss = 0.0001
# epoch = 78, train_loss = 0.0001, test_loss = 0.0001
# epoch = 79, train_loss = 0.0001, test_loss = 0.0001
# epoch = 80, train_loss = 0.0001, test_loss = 0.0001
# epoch = 81, train_loss = 0.0001, test_loss = 0.0001
# epoch = 82, train_loss = 0.0001, test_loss = 0.0001
# epoch = 83, train_loss = 0.0001, test_loss = 0.0001
# epoch = 84, train_loss = 0.0001, test_loss = 0.0001
# epoch = 85, train_loss = 0.0001, test_loss = 0.0001
# epoch = 86, train_loss = 0.0001, test_loss = 0.0001
# epoch = 87, train_loss = 0.0001, test_loss = 0.0001
# epoch = 88, train_loss = 0.0001, test_loss = 0.0001
# epoch = 89, train_loss = 0.0001, test_loss = 0.0001
# epoch = 90, train_loss = 0.0001, test_loss = 0.0001
# epoch = 91, train_loss = 0.0001, test_loss = 0.0001
# epoch = 92, train_loss = 0.0001, test_loss = 0.0001
# epoch = 93, train_loss = 0.0001, test_loss = 0.0001
# epoch = 94, train_loss = 0.0001, test_loss = 0.0001
# epoch = 95, train_loss = 0.0001, test_loss = 0.0001
# epoch = 96, train_loss = 0.0001, test_loss = 0.0001
# epoch = 97, train_loss = 0.0001, test_loss = 0.0001
# epoch = 98, train_loss = 0.0001, test_loss = 0.0001
# epoch = 99, train_loss = 0.0001, test_loss = 0.0001
# --------worm No. 5--------
# epoch = 0, train_loss = 0.0002, test_loss = 0.0003
# epoch = 1, train_loss = 0.0002, test_loss = 0.0003
# epoch = 2, train_loss = 0.0002, test_loss = 0.0003
# epoch = 3, train_loss = 0.0002, test_loss = 0.0003
# epoch = 4, train_loss = 0.0002, test_loss = 0.0003
# epoch = 5, train_loss = 0.0002, test_loss = 0.0003
# epoch = 6, train_loss = 0.0002, test_loss = 0.0002
# epoch = 7, train_loss = 0.0002, test_loss = 0.0002
# epoch = 8, train_loss = 0.0002, test_loss = 0.0002
# epoch = 9, train_loss = 0.0002, test_loss = 0.0002
# epoch = 10, train_loss = 0.0002, test_loss = 0.0002
# epoch = 11, train_loss = 0.0001, test_loss = 0.0002
# epoch = 12, train_loss = 0.0001, test_loss = 0.0002
# epoch = 13, train_loss = 0.0001, test_loss = 0.0002
# epoch = 14, train_loss = 0.0001, test_loss = 0.0002
# epoch = 15, train_loss = 0.0001, test_loss = 0.0002
# epoch = 16, train_loss = 0.0001, test_loss = 0.0002
# epoch = 17, train_loss = 0.0001, test_loss = 0.0002
# epoch = 18, train_loss = 0.0001, test_loss = 0.0002
# epoch = 19, train_loss = 0.0001, test_loss = 0.0002
# epoch = 20, train_loss = 0.0001, test_loss = 0.0002
# epoch = 21, train_loss = 0.0001, test_loss = 0.0002
# epoch = 22, train_loss = 0.0001, test_loss = 0.0002
# epoch = 23, train_loss = 0.0001, test_loss = 0.0002
# epoch = 24, train_loss = 0.0001, test_loss = 0.0002
# epoch = 25, train_loss = 0.0001, test_loss = 0.0002
# epoch = 26, train_loss = 0.0001, test_loss = 0.0002
# epoch = 27, train_loss = 0.0001, test_loss = 0.0002
# epoch = 28, train_loss = 0.0001, test_loss = 0.0002
# epoch = 29, train_loss = 0.0001, test_loss = 0.0002
# epoch = 30, train_loss = 0.0001, test_loss = 0.0002
# epoch = 31, train_loss = 0.0001, test_loss = 0.0002
# epoch = 32, train_loss = 0.0001, test_loss = 0.0002
# epoch = 33, train_loss = 0.0001, test_loss = 0.0002
# epoch = 34, train_loss = 0.0001, test_loss = 0.0002
# epoch = 35, train_loss = 0.0001, test_loss = 0.0002
# epoch = 36, train_loss = 0.0001, test_loss = 0.0002
# epoch = 37, train_loss = 0.0001, test_loss = 0.0001
# epoch = 38, train_loss = 0.0001, test_loss = 0.0001
# epoch = 39, train_loss = 0.0001, test_loss = 0.0002
# epoch = 40, train_loss = 0.0001, test_loss = 0.0001
# epoch = 41, train_loss = 0.0001, test_loss = 0.0001
# epoch = 42, train_loss = 0.0001, test_loss = 0.0001
# epoch = 43, train_loss = 0.0001, test_loss = 0.0001
# epoch = 44, train_loss = 0.0001, test_loss = 0.0001
# epoch = 45, train_loss = 0.0001, test_loss = 0.0001
# epoch = 46, train_loss = 0.0001, test_loss = 0.0001
# epoch = 47, train_loss = 0.0001, test_loss = 0.0001
# epoch = 48, train_loss = 0.0001, test_loss = 0.0001
# epoch = 49, train_loss = 0.0001, test_loss = 0.0001
# epoch = 50, train_loss = 0.0001, test_loss = 0.0001
# epoch = 51, train_loss = 0.0001, test_loss = 0.0001
# epoch = 52, train_loss = 0.0001, test_loss = 0.0001
# epoch = 53, train_loss = 0.0001, test_loss = 0.0001
# epoch = 54, train_loss = 0.0001, test_loss = 0.0001
# epoch = 55, train_loss = 0.0001, test_loss = 0.0001
# epoch = 56, train_loss = 0.0001, test_loss = 0.0001
# epoch = 57, train_loss = 0.0001, test_loss = 0.0001
# epoch = 58, train_loss = 0.0001, test_loss = 0.0001
# epoch = 59, train_loss = 0.0001, test_loss = 0.0001
# epoch = 60, train_loss = 0.0001, test_loss = 0.0001
# epoch = 61, train_loss = 0.0001, test_loss = 0.0001
# epoch = 62, train_loss = 0.0001, test_loss = 0.0001
# epoch = 63, train_loss = 0.0001, test_loss = 0.0001
# epoch = 64, train_loss = 0.0001, test_loss = 0.0001
# epoch = 65, train_loss = 0.0001, test_loss = 0.0001
# epoch = 66, train_loss = 0.0001, test_loss = 0.0001
# epoch = 67, train_loss = 0.0001, test_loss = 0.0001
# epoch = 68, train_loss = 0.0001, test_loss = 0.0001
# epoch = 69, train_loss = 0.0001, test_loss = 0.0001
# epoch = 70, train_loss = 0.0001, test_loss = 0.0001
# epoch = 71, train_loss = 0.0001, test_loss = 0.0001
# epoch = 72, train_loss = 0.0001, test_loss = 0.0001
# epoch = 73, train_loss = 0.0001, test_loss = 0.0001
# epoch = 74, train_loss = 0.0001, test_loss = 0.0001
# epoch = 75, train_loss = 0.0001, test_loss = 0.0001
# epoch = 76, train_loss = 0.0001, test_loss = 0.0001
# epoch = 77, train_loss = 0.0001, test_loss = 0.0001
# epoch = 78, train_loss = 0.0001, test_loss = 0.0001
# epoch = 79, train_loss = 0.0001, test_loss = 0.0001
# epoch = 80, train_loss = 0.0001, test_loss = 0.0001
# epoch = 81, train_loss = 0.0001, test_loss = 0.0001
# epoch = 82, train_loss = 0.0001, test_loss = 0.0001
# epoch = 83, train_loss = 0.0001, test_loss = 0.0001
# epoch = 84, train_loss = 0.0001, test_loss = 0.0001
# epoch = 85, train_loss = 0.0001, test_loss = 0.0001
# epoch = 86, train_loss = 0.0001, test_loss = 0.0001
# epoch = 87, train_loss = 0.0001, test_loss = 0.0001
# epoch = 88, train_loss = 0.0001, test_loss = 0.0001
# epoch = 89, train_loss = 0.0001, test_loss = 0.0001
# epoch = 90, train_loss = 0.0001, test_loss = 0.0001
# epoch = 91, train_loss = 0.0001, test_loss = 0.0001
# epoch = 92, train_loss = 0.0001, test_loss = 0.0001
# epoch = 93, train_loss = 0.0001, test_loss = 0.0001
# epoch = 94, train_loss = 0.0001, test_loss = 0.0001
# epoch = 95, train_loss = 0.0001, test_loss = 0.0001
# epoch = 96, train_loss = 0.0001, test_loss = 0.0001
# epoch = 97, train_loss = 0.0001, test_loss = 0.0001
# epoch = 98, train_loss = 0.0001, test_loss = 0.0001
# epoch = 99, train_loss = 0.0001, test_loss = 0.0001

# %%
print(dataset["worm0"]["dataset"])
# Out:
# Uzel2022

# %%
if smoothed:
    calcium_data = dataset[worm]["smooth_calcium_data"]
    residual_calcium = dataset[worm]["residual_smooth_calcium"]
else:
    calcium_data = dataset[worm]["calcium_data"]
    residual_calcium = dataset[worm]["residual_calcium"]
# visualization of prediction
pred = []
target = []
X_test = []
Y_test = []

num_neurons = 302
for i in range(time_step, calcium_data.shape[0] - 1):
    X, Y = (
        calcium_data[i - time_step : i, :num_neurons],
        calcium_data[i - time_step + 1 : i + 1, :num_neurons],
    )
    X_test.append(np.array(X))
    Y_test.append(np.array(Y))

X_test = torch.tensor(np.array(X_test))
Y_test = torch.tensor(np.array(Y_test))
print(X_test.shape)
optimizer.zero_grad()  # Clear gradients.
mask_test = dataset["worm0"]["named_neurons_mask"]
mask_test = mask_test.repeat(Y_test.shape[1], 1)
mask_test = mask_test.unsqueeze(0)
mask_test = mask_test.repeat(Y_test.shape[0], 1, 1)
Y_test = Y_test * mask_test
Y_pred = model(X_test * mask_test)
print(X_test.shape)
Y_pred = Y_pred
print(Y_pred.shape, Y_test.shape)
# Out:
# torch.Size([3301, 10, 302])
# torch.Size([3301, 10, 302])
# torch.Size([3301, 10, 302]) torch.Size([3301, 10, 302])

# %%
def draw_pic(Y_pred, Y_test, num, time):
    plt.plot(Y_test.detach().numpy()[:time, 0, num])
    plt.plot(Y_pred.detach().numpy()[:time, 0, num])
    plt.legend(["target", "pred"], loc="upper right")
    plt.title(
        "Cal to Res Prediction\n" + "Neuron No: " + str(num) + "   Time: 0-" + str(time)
    )
    plt.show()


draw_pic(Y_pred, Y_test, 0, dataset["worm0"]["max_time"])

draw_pic(Y_pred, Y_test, 1, dataset["worm0"]["max_time"])

draw_pic(Y_pred, Y_test, 60, dataset["worm0"]["max_time"])

draw_pic(Y_pred, Y_test, 120, dataset["worm0"]["max_time"])

draw_pic(Y_pred, Y_test, 300, dataset["worm0"]["max_time"])

# %%
for i in range(6):
    # plt.plot(dataset["worm"+str(i)]["calcium_data"][:, 0])
    # plt.plot(dataset["worm"+str(i)]["calcium_data"][:, 60])
    print(dataset["worm" + str(i)]["named_neurons_mask"][0])
    print(dataset["worm" + str(i)]["named_neurons_mask"][60])
    plt.show()
# Out:
# tensor(False)
# tensor(True)
# tensor(False)
# tensor(True)
# tensor(False)
# tensor(True)
# tensor(False)
# tensor(True)
# tensor(False)
# tensor(True)
# tensor(False)
# tensor(True)
