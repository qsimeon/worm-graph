# %% [markdown]
# # Imports and Setup

# %%
# %load_ext cudf.pandas
# %matplotlib inline

import os
import ast
import numpy as np
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
import matplotlib.gridspec as gridspec

from scipy import stats
from utils import NUM_NEURONS
from pprint import PrettyPrinter
from matplotlib.lines import Line2D
from utils import init_random_seeds
from matplotlib.patches import Patch
from visualize._utils import experiment_parameter
from statsmodels.nonparametric.smoothers_lowess import lowess

# Some plot/display settings
sns.set_style("whitegrid")
pp = PrettyPrinter(indent=4, width=100, compact=True)

# Initialize the random seeds
init_random_seeds(42)
# Out:
# CUDA device found.
# 	 GPU: NVIDIA A100 80GB PCIe

# %% [markdown]
# # Color and Marker Legend
# Returns the common legend code used for all plots.

# %%
# 1. Marker and Dataset color codes
def legend_code():
    # Define the markers and labels
    markers = {
        "<": "Naive",
        ">": "Linear",
        "v": "Feedforward",
        "X": "Transformer",
        "P": "Attention",  # potentially EXCLUDE
        "o": "LSTM",
        "s": "CTRNN",
        "*": "SSM",  # potentially EXCLUDE
        "p": "Liquid",  # potentially EXCLUDE
    }
    markers = {value: key for key, value in markers.items()}

    model_labels = {
        "NaivePredictor": "Naive",
        "LinearRegression": "Linear",
        "FeatureFFNN": "Feedforward",
        "NeuralTransformer": "Transformer",
        "PureAttention": "Attention",
        "NetworkLSTM": "LSTM",
        "NetworkCTRNN": "CTRNN",
        "HippoSSM": "SSM",
        "LiquidCfC": "Liquid",  # potentially EXCLUDE
    }

    dataset_labels = {
        # experimental datasets
        "Kato2015": "Kato (2015)",
        "Nichols2017": "Nichols (2017)",
        "Skora2018": "Skora (2018)",
        "Kaplan2020": "Kaplan (2020)",
        "Yemini2021": "Yemini (2021)",
        "Uzel2022": "Uzel (2022)",
        "Dag2023": "Dag (2023)",
        "Flavell2023": "Flavell (2023)",
        "Leifer2023": "Leifer (2023)",
        "Lin2023": "Lin (2023)",
        "Venkatachalam2024": "Venkatachalam (2024)",
    }

    # Get the full color maps
    full_model_palette = sns.color_palette("twilight_shifted")
    full_dataset_palette = sns.color_palette("tab20c")

    # Calculate equidistant indices for the number of model and datasets
    model_indices = np.linspace(
        0, len(full_model_palette), len(model_labels), endpoint=False, dtype=int
    )
    dataset_indices = np.linspace(
        0, len(full_dataset_palette), len(dataset_labels), endpoint=False, dtype=int
    )

    # Sample colors equidistantly from the colormaps
    model_color_palette = [full_model_palette[i] for i in model_indices]
    dataset_color_palette = [full_dataset_palette[i] for i in dataset_indices]

    # Create custom markers for model
    marker_legend = [
        Line2D(
            [0],
            [0],
            marker=markers[model_labels[model]],
            color=model_color_palette[i],
            label=model_labels[model],
            linestyle="None",
        )
        for i, model in enumerate(model_labels)
    ]

    # Create rectangular color patches for datasets
    color_legend = [
        Patch(
            facecolor=dataset_color_palette[i],
            edgecolor=dataset_color_palette[i],
            label=dataset_labels[dataset],
        )
        for i, dataset in enumerate(dataset_labels)
    ]

    # Construct the color code dictionaries
    model_color_code = {
        model: model_color_palette[i] for i, model in enumerate(model_labels.values())
    }
    dataset_color_code = {
        dataset: dataset_color_palette[i] for i, dataset in enumerate(dataset_labels)
    }

    # Plot the legends
    fig, axs = plt.subplots(1, 2, figsize=(8, 2))

    # Model legend
    axs[0].legend(handles=marker_legend, loc="center", title="Model", frameon=False)
    axs[0].axis("off")

    # Dataset legend
    axs[1].legend(handles=color_legend, loc="center", title="Experimental datasets", frameon=False)
    axs[1].axis("off")

    plt.tight_layout()
    plt.show()

    leg_code = {
        "dataset_color_code": dataset_color_code,
        "model_color_code": model_color_code,
        "color_legend": color_legend,
        "dataset_labels": dataset_labels,
        "marker_legend": marker_legend,
        "model_labels": model_labels,
        "model_marker_code": markers,
    }

    return leg_code


# Usage example
leg_code = legend_code()
pp.pprint(leg_code)
# Out:
# {   'color_legend': [   <matplotlib.patches.Patch object at 0x153f070371d0>,
#                         <matplotlib.patches.Patch object at 0x153f07a06650>,
#                         <matplotlib.patches.Patch object at 0x153f07040c50>,
#                         <matplotlib.patches.Patch object at 0x153f07040f10>,
#                         <matplotlib.patches.Patch object at 0x153f079d8d10>,
#                         <matplotlib.patches.Patch object at 0x153f070412d0>,
#                         <matplotlib.patches.Patch object at 0x153f07041750>,
#                         <matplotlib.patches.Patch object at 0x153f07041a10>,
#                         <matplotlib.patches.Patch object at 0x153f07041cd0>,
#                         <matplotlib.patches.Patch object at 0x153f07041450>,
#                         <matplotlib.patches.Patch object at 0x153f07042210>],
#     'dataset_color_code': {   'Dag2023': (   0.6313725490196078, 0.8509803921568627,
#                                              0.6078431372549019),
#                               'Flavell2023': (   0.7372549019607844, 0.7411764705882353,
#                                                  0.8627450980392157),
#                               'Kaplan2020': (   0.9921568627450981, 0.5529411764705883,
#                                                 0.23529411764705882),
#                               'Kato2015': (   0.19215686274509805, 0.5098039215686274,
#                                               0.7411764705882353),
#                               'Leifer2023': (   0.38823529411764707, 0.38823529411764707,
#                                                 0.38823529411764707),
#                               'Lin2023': (   0.4588235294117647, 0.4196078431372549,
#                                              0.6941176470588235),
#                               'Nichols2017': (   0.4196078431372549, 0.6823529411764706,
#                                                  0.8392156862745098),
#                               'Skora2018': (   0.7764705882352941, 0.8588235294117647,
#                                                0.9372549019607843),
#                               'Uzel2022': (   0.4549019607843137, 0.7686274509803922,
#                                               0.4627450980392157),
#                               'Venkatachalam2024': (   0.7411764705882353, 0.7411764705882353,
#                                                        0.7411764705882353),
#                               'Yemini2021': (   0.9921568627450981, 0.8156862745098039,
#                                                 0.6352941176470588)},
#     'dataset_labels': {   'Dag2023': 'Dag (2023)',
#                           'Flavell2023': 'Flavell (2023)',
#                           'Kaplan2020': 'Kaplan (2020)',
#                           'Kato2015': 'Kato (2015)',
#                           'Leifer2023': 'Leifer (2023)',
#                           'Lin2023': 'Lin (2023)',
#                           'Nichols2017': 'Nichols (2017)',
#                           'Skora2018': 'Skora (2018)',
#                           'Uzel2022': 'Uzel (2022)',
#                           'Venkatachalam2024': 'Venkatachalam (2024)',
#                           'Yemini2021': 'Yemini (2021)'},
#     'marker_legend': [   <matplotlib.lines.Line2D object at 0x153f07036690>,
#                          <matplotlib.lines.Line2D object at 0x153f0799d090>,
#                          <matplotlib.lines.Line2D object at 0x153f07442f90>,
#                          <matplotlib.lines.Line2D object at 0x153f0815d9d0>,
#                          <matplotlib.lines.Line2D object at 0x153f07036ed0>,
#                          <matplotlib.lines.Line2D object at 0x153f07037510>,
#                          <matplotlib.lines.Line2D object at 0x153f07037490>,
#                          <matplotlib.lines.Line2D object at 0x153f07037c50>,
#                          <matplotlib.lines.Line2D object at 0x153f07040150>],
#     'model_color_code': {   'Attention': (   0.7387377170049494, 0.7959766573503101,
#                                              0.8214292278043301),
#                             'CTRNN': (0.7387914002459927, 0.4205367299231533, 0.34913260148542435),
#                             'Feedforward': (   0.4113541469730457, 0.5368485776500593,
#                                                0.7466971285506578),
#                             'LSTM': (0.8398783988412087, 0.7603990719977968, 0.7136714781112923),
#                             'Linear': (   0.36002681809096376, 0.20694122817889948,
#                                           0.6029284543191687),
#                             'Liquid': (0.4981443546207415, 0.13569380302451714, 0.314135190862664),
#                             'Naive': (0.36002681809096376, 0.20694122817889948, 0.6029284543191687),
#                             'SSM': (0.7387914002459927, 0.4205367299231533, 0.34913260148542435),
#                             'Transformer': (   0.7387377170049494, 0.7959766573503101,
#                                                0.8214292278043301)},
#     'model_labels': {   'FeatureFFNN': 'Feedforward',
#                         'HippoSSM': 'SSM',
#                         'LinearRegression': 'Linear',
#                         'LiquidCfC': 'Liquid',
#                         'NaivePredictor': 'Naive',
#                         'NetworkCTRNN': 'CTRNN',
#                         'NetworkLSTM': 'LSTM',
#                         'NeuralTransformer': 'Transformer',
#                         'PureAttention': 'Attention'},
#     'model_marker_code': {   'Attention': 'P',
#                              'CTRNN': 's',
#                              'Feedforward': 'v',
#                              'LSTM': 'o',
#                              'Linear': '>',
#                              'Liquid': 'p',
#                              'Naive': '<',
#                              'SSM': '*',
#                              'Transformer': 'X'}}

# %% [markdown]
# # Dataset information

# %%
# %%cudf.pandas.profile


# 2. Plotting summary information about the datasets
def dataset_information(path_dict, legend_code):
    """
    path_dict: dictionary with the path to train_dataset_info,
        validation_dataset_info and full_dataset_info.
    """
    # ### LOAD IN DATASET INFORMATION ###
    # Load the dataframes contianing information about the datasets
    train_dataset_info = pd.read_csv(
        path_dict["train_dataset_info"],
        converters={"neurons": ast.literal_eval},
    )
    val_dataset_info = pd.read_csv(
        path_dict["val_dataset_info"],
        converters={"neurons": ast.literal_eval},
    )
    full_dataset_info = pd.read_csv(
        path_dict["full_dataset_info"],
        converters={"neurons": ast.literal_eval},
    )
    # Compute certain quantities from the dataset information
    train_dataset_info["total_time_steps"] = (
        train_dataset_info["train_time_steps"] + val_dataset_info["val_time_steps"]
    )
    train_dataset_info["time_steps_per_neuron"] = (
        train_dataset_info["total_time_steps"] / train_dataset_info["num_neurons"]
    )
    amount_of_data_distribution = (
        train_dataset_info[["source_dataset", "total_time_steps"]]
        .groupby("source_dataset")
        .sum()
        .sort_values(by="total_time_steps", ascending=False)
    )
    amount_of_data_distribution["percentage"] = (
        amount_of_data_distribution["total_time_steps"]
        / amount_of_data_distribution["total_time_steps"].sum()
    )
    delta_t = round(
        train_dataset_info["median_dt"].median(), 3
    )  # get directly from `train_dataset_info`

    # ########### SET UP FOR FIGURES ###########
    # Get color code and legend from legend_code
    dataset_color_code = legend_code["dataset_color_code"]
    dataset_labels = legend_code["dataset_labels"]
    color_legend = legend_code["color_legend"]

    # Initialize figure
    fig = plt.figure(figsize=(20, 11))
    gs = gridspec.GridSpec(2, 4, height_ratios=[1, 1], width_ratios=[1, 1, 1, 0.25])

    # Assigning the subplots to positions in the grid
    ax1 = plt.subplot(gs[0, 0])  # Top left, 'Number of worms analyzed' pie chart
    ax2 = plt.subplot(gs[0, 1])  # Top right, 'Number of neurons per worm' bar plot
    ax3 = plt.subplot(
        gs[1, 0]
    )  # Bottom left, 'Total duration of recorded neural activity' pie chart
    ax4 = plt.subplot(
        gs[1, 1]
    )  # Bottom middle, 'Duration of recorded neural activity per worm' bar plot
    ax5 = plt.subplot(gs[0, 3])  # Bottom right, legend
    ax6 = plt.subplot(gs[0, 2])
    ax7 = plt.subplot(gs[1, 2:4])

    # ########### FOR WORMS PIE CHART ###############
    num_worms_per_dataset = full_dataset_info[["source_dataset", "original_index"]]
    # Count the unique 'original_index' for each 'dataset'
    num_worms_per_dataset = (
        num_worms_per_dataset.groupby("source_dataset")["original_index"]
        .nunique()
        .reset_index(name="num_worms")
    )
    # Calculate the percentage for each dataset
    num_worms_per_dataset["percentage"] = (
        num_worms_per_dataset["num_worms"] / num_worms_per_dataset["num_worms"].sum()
    )
    # Sort the values by percentage in descending order
    num_worms_per_dataset = num_worms_per_dataset.sort_values(by="percentage", ascending=False)
    h = 2  # this just hides the last `h` labels to declutter the pie chart
    worm_count_label = num_worms_per_dataset["num_worms"][:-h].tolist() + h * [""]
    worm_percent_label = num_worms_per_dataset["percentage"]
    # Plotting the worms per dataset pie chart
    ax1.pie(
        num_worms_per_dataset["num_worms"],
        labels=[f"{p:.1%}" for p in worm_percent_label],
        labeldistance=1.075,
        startangle=45,
        textprops={"fontsize": 10},
        colors=[dataset_color_code[dataset] for dataset in num_worms_per_dataset["source_dataset"]],
    )
    # NOTE: This plots over the first pie chart; since we placed the labels above on the perimeter, we can still see them
    ax1.pie(
        num_worms_per_dataset["num_worms"],
        labels=[f"{n}" for n in worm_count_label],
        labeldistance=0.70,
        startangle=45,
        textprops={"fontsize": 10},
        colors=[dataset_color_code[dataset] for dataset in num_worms_per_dataset["source_dataset"]],
    )
    ax1.set_title("(A) Number of worms in each experimental dataset", fontsize=14)

    # ########### NEURON POPULATION DISTRIBUTION BAR PLOT ###############
    ax2 = plt.subplot(gs[0, 1])  # Subplot for 'Number of neurons per worm' bar plot
    # Compute data for the neuron population distribution bar plot
    neuron_pop_stats = (
        train_dataset_info.groupby("source_dataset")["num_neurons"]
        .agg(["mean", "sem"])
        .reset_index()
        .sort_values(by="mean", ascending=False)
    )
    neuron_pop_colors = neuron_pop_stats["source_dataset"].apply(
        lambda x: dataset_color_code.get(x, "grey")
    )
    ax2.bar(
        neuron_pop_stats["source_dataset"],
        neuron_pop_stats["mean"],
        yerr=2 * neuron_pop_stats["sem"],
        color=neuron_pop_colors,
        capsize=5,
    )
    # Add a dashed horizontal line at y=NUM_NEURONS
    ax2.axhline(y=NUM_NEURONS, color="black", linestyle="dashed", linewidth=1, alpha=0.5)
    # Annotate the line
    # Use the right edge of the subplot for text annotation to prevent overflow
    right_edge = ax2.get_xlim()[1]
    ax2.text(
        right_edge,  # x position at the right edge
        NUM_NEURONS + 3.0,  # y position just above the line
        "Number of neurons in C. elegans hermaphrodite",
        horizontalalignment="right",  # Align text to the right
        fontsize=12,
        fontstyle="italic",
    )
    ax2.set_title("(B) Number of recorded neurons per worm", fontsize=14)
    ax2.set_ylabel("Neuron population size")
    ax2.set_xticklabels(neuron_pop_stats["source_dataset"], rotation=45, ha="right")
    ax2.set_xticks([])  # Delete xticks

    # ########### TOTAL DURATION OF RECORDED NEURAL ACTIVITY PIE CHART ###############
    ax3 = plt.subplot(
        gs[1, 0]
    )  # Subplot for 'Total duration of recorded neural activity' pie chart
    # Compute data for total duration pie chart
    total_duration_stats = (
        train_dataset_info.groupby("source_dataset")["total_time_steps"]
        .sum()
        .reset_index()
        .sort_values(by="total_time_steps", ascending=False)
    )
    total_duration_stats["percentage"] = (
        total_duration_stats["total_time_steps"] / total_duration_stats["total_time_steps"].sum()
    )

    # Determine the smallest slice
    smallest_slice_index = total_duration_stats["percentage"].idxmin()

    # Generate labels, omitting the smallest slice
    labels = [
        f"{percentage:.1%}" if i != smallest_slice_index else ""
        for i, percentage in enumerate(total_duration_stats["percentage"])
    ]

    total_duration_colors = total_duration_stats["source_dataset"].apply(
        lambda x: dataset_color_code.get(x, "grey")
    )
    # Plotting the total duration pie chart
    ax3.pie(
        total_duration_stats["total_time_steps"],
        labels=labels,
        labeldistance=1.075,
        startangle=90,
        textprops={"fontsize": 10},
        colors=total_duration_colors,
    )
    ax3.set_title("(C) Total duration of recorded neural activity", fontsize=14)

    # ########### DURATION OF RECORDED NEURAL ACTIVITY PER WORM BAR PLOT ###############
    ax4 = plt.subplot(
        gs[1, 1]
    )  # Subplot for 'Duration of recorded neural activity per worm' bar plot
    # Compute data for recording duration bar plot
    recording_duration_stats = (
        train_dataset_info.groupby("source_dataset")["total_time_steps"]
        .agg(["mean", "sem"])
        .reset_index()
        .sort_values(by="mean", ascending=False)
    )
    recording_duration_colors = recording_duration_stats["source_dataset"].apply(
        lambda x: dataset_color_code.get(x, "grey")
    )
    ax4.bar(
        recording_duration_stats["source_dataset"],
        recording_duration_stats["mean"] / delta_t,
        yerr=2 * recording_duration_stats["sem"],
        color=recording_duration_colors,
        capsize=5,
    )
    hour_tsteps = 3600 / delta_t  # 1 hour = 3600 seconds
    # Add a dashed horizontal line at 3600 converted to time steps
    ax4.axhline(y=hour_tsteps, color="black", linestyle="dashed", linewidth=1, alpha=0.5)
    # Annotate the line
    # Use the right edge of the subplot for text annotation to prevent overflow
    right_edge = ax4.get_xlim()[1]
    ax4.text(
        right_edge,  # x position at the right edge
        hour_tsteps + 100.0,  # y position just above the line
        "Equivalent to 1 hour of calcium imaging",
        horizontalalignment="right",  # Align text to the right
        fontsize=12,
        fontstyle="italic",
    )
    ax4.set_title("(D) Duration of recorded neural activity per worm", fontsize=14)
    ax4.set_ylabel("Time (s)")
    ax4.set_xticklabels(recording_duration_stats["source_dataset"], rotation=45, ha="right")
    ax4.set_xticks([])  # Delete xticks

    # ########### TIME STEPS PER NEURON BAR PLOT ###############
    ax6 = plt.subplot(gs[0, 2])  # Subplot for 'Number of time steps per recorded neuron' bar plot
    # Compute data for time steps per neuron bar plot
    tsn_stats = (
        train_dataset_info.groupby("source_dataset")["time_steps_per_neuron"]
        .agg(["mean", "sem"])
        .reset_index()
        .sort_values(by="mean", ascending=False)
    )
    tsn_colors = tsn_stats["source_dataset"].apply(lambda x: dataset_color_code.get(x, "grey"))
    ax6.bar(
        tsn_stats["source_dataset"],
        tsn_stats["mean"],
        yerr=2 * tsn_stats["sem"],
        color=tsn_colors,
        capsize=5,
    )
    seq_len = int(train_dataset_info["train_seq_len"].median())
    # Add a dashed horizontal line at y=100
    ax6.axhline(y=seq_len, color="black", linestyle="dashed", linewidth=1, alpha=0.5)
    # Annotate the line
    # Use the right edge of the subplot for text annotation to prevent overflow
    right_edge = ax6.get_xlim()[1]
    ax6.text(
        right_edge,  # x position at the right edge
        seq_len + 3.0,  # y position just above the line
        f"Sequence length $L={seq_len}$ was used in our experiments",
        horizontalalignment="right",  # Align text to the right
        fontsize=12,
        fontstyle="italic",
    )
    ax6.set_title("(E) Number of sampled time steps per neuron", fontsize=14)
    ax6.set_ylabel("Time steps per neuron")
    ax6.set_xticklabels(tsn_stats["source_dataset"], rotation=45, ha="right")
    ax6.set_xticks([])  # Delete xticks

    # ########### SAMPLING INTERVAL BAR PLOT ###############
    ax7 = plt.subplot(
        gs[1, 2:4]
    )  # Subplot for 'Sampling interval of recorded neural activity' bar plot
    # Compute data for the sampling interval bar plot
    dt_stats = (
        train_dataset_info.groupby("source_dataset")["original_median_dt"]
        .agg(["mean", "sem"])
        .reset_index()
        .sort_values(by="mean", ascending=False)
    )
    dt_colors = dt_stats["source_dataset"].apply(lambda x: dataset_color_code.get(x, "grey"))
    ax7.bar(
        dt_stats["source_dataset"],
        dt_stats["mean"],
        yerr=2 * dt_stats["sem"],
        color=dt_colors,
        capsize=5,
    )
    # Add a dashed horizontal line at y=1.0
    ax7.axhline(y=delta_t, color="black", linestyle="dashed", linewidth=1, alpha=0.5)
    # Annotate the line
    # Use the right edge of the subplot for text annotation to prevent overflow
    right_edge = ax7.get_xlim()[1]
    left_edge = ax7.get_xlim()[0]
    middle = (right_edge + left_edge) / 2
    ax7.text(
        1.30 * middle,  # x position at the right edge
        delta_t + 0.005,  # y position just above the line
        f"We resampled all datasets to $\Delta s ≈ {delta_t}s$ ({round(1/delta_t, 1)} Hz)",
        horizontalalignment="right",  # Align text to the right
        fontsize=12,
        fontstyle="italic",
    )
    ax7.set_title("(F) Sampling interval of recorded neural activity", fontsize=14)
    ax7.set_ylabel(r"Mean sampling interval ($\Delta$s)")
    ax7.set_xticklabels(dt_stats["source_dataset"], rotation=45, ha="right")
    ax7.set_xticks([])  # Delete xticks

    # ########### LEGEND SUBPLOT ###############
    ax5 = plt.subplot(gs[0, 3])  # Subplot for legend
    ax5.legend(
        handles=color_legend,
        labels=dataset_labels.values(),  # DEBUG
        loc="center",
        title="Experimental datasets",
        fontsize=11,
        title_fontsize=12,
    )
    ax5.get_legend().get_title().set_fontstyle("italic")
    ax5.axis("off")

    plt.tight_layout()
    plt.show()

    # Construct and return the dataset_info dictionary with all the computed stats
    dataset_info = {
        "train_dataset_info": train_dataset_info,
        "amount_of_data_distribution": amount_of_data_distribution,
        "num_worms_per_dataset": num_worms_per_dataset,
        "total_duration_stats": total_duration_stats,
        "neuron_pop_stats": neuron_pop_stats,
        "recording_duration_stats": recording_duration_stats,
        "tsn_stats": tsn_stats,
        "dt_stats": dt_stats,
    }

    return dataset_info

# %%
# Usage example
fig1_path_dict = {
    "train_dataset_info": "/om2/user/qsimeon/worm-graph/data/combined_AllExperimental/train_dataset_info.csv",  # Path to train dataset info => extract number of train time steps
    "val_dataset_info": "/om2/user/qsimeon/worm-graph/data/combined_AllExperimental/val_dataset_info.csv",  # Path to val. dataset info => extract number of val. time steps
    "full_dataset_info": "/om2/user/qsimeon/worm-graph/data/combined_AllExperimental/full_dataset_info.csv",  # Path to combined dataset info => extract total number of worms and time step interval
}

# NOTE: Error bars on bar plots show +/- 2 SEM
dataset_info = dataset_information(path_dict=fig1_path_dict, legend_code=leg_code)

# %% [markdown]
# # Scaling Law Figures

# %%
# %%cudf.pandas.profile


def get_results_df(results_root_dir):
    """
    Recursively traverses the experiment directories, reads train_metrics.csv and
    validation_loss_per_dataset.csv files, and combines the data into a comprehensive DataFrame.

    Parameters:
    - results_root_dir: The root directory where the experiment directories are located.

    Returns:
    - A DataFrame containing all the combined results from the experiments.
    """

    def recursive_search(path, results):
        """
        Helper function to perform a recursive search for csv files in the directory tree.
        """
        for entry in os.scandir(path):
            if entry.is_dir() and any(os.scandir(entry.path)):
                recursive_search(entry.path, results)
            elif entry.is_file():
                if entry.name == "train_metrics.csv":
                    train_metrics_path = entry.path
                    validation_loss_path = os.path.join(
                        os.path.dirname(os.path.dirname(train_metrics_path)),
                        "analysis",
                        "validation_loss_per_dataset.csv",
                    )

                    if os.path.exists(validation_loss_path):
                        # Read the csv files
                        train_metrics_df = pd.read_csv(train_metrics_path)
                        validation_loss_df = pd.read_csv(validation_loss_path)

                        # Extract parameters using the provided experiment_parameter function
                        exp_path = os.path.dirname(os.path.dirname(train_metrics_path))
                        experiment_seed = experiment_parameter(exp_path, "experiment_seed")[0]
                        train_dataset = experiment_parameter(exp_path, "train_dataset")[0]
                        num_worms = experiment_parameter(exp_path, "num_worms")[0]
                        num_time_steps = experiment_parameter(exp_path, "num_time_steps")[0]
                        num_labeled_neurons = experiment_parameter(exp_path, "num_labeled_neurons")[0]
                        time_steps_per_neuron = experiment_parameter(
                            exp_path, "time_steps_per_neuron"
                        )[0]
                        train_split_first = experiment_parameter(exp_path, "train_split_first")[0]
                        hidden_size = experiment_parameter(exp_path, "hidden_size")[0]
                        batch_size = experiment_parameter(exp_path, "batch_size")[0]
                        seq_len = experiment_parameter(exp_path, "seq_len")[0]
                        resample_dt = experiment_parameter(exp_path, "resample_dt")[0]
                        time_last_epoch = experiment_parameter(exp_path, "time_last_epoch")[0]
                        computation_flops = experiment_parameter(exp_path, "computation_flops")[0]
                        num_parameters = experiment_parameter(exp_path, "num_parameters")[0]
                        model_type = experiment_parameter(exp_path, "model")[0]

                        # Calculate the min_val_loss and val_baseline
                        min_val_loss = train_metrics_df["val_loss"].min()
                        val_baseline = train_metrics_df["val_baseline"].mean()

                        # Append data to the results list
                        for _, row in validation_loss_df.iterrows():
                            results.append(
                                {
                                    "experiment_ID": os.path.basename(exp_path),
                                    "experiment_seed": experiment_seed,
                                    "train_dataset": train_dataset,
                                    "num_worms": num_worms,
                                    "num_time_steps": num_time_steps,
                                    "num_labeled_neurons": num_labeled_neurons,
                                    "time_steps_per_neuron": time_steps_per_neuron,
                                    "train_split_first": train_split_first,
                                    "hidden_size": hidden_size,
                                    "batch_size": batch_size,
                                    "seq_len": seq_len,
                                    "resample_dt": resample_dt,
                                    "time_last_epoch": time_last_epoch,
                                    "computation_flops": computation_flops,
                                    "num_parameters": num_parameters,
                                    "model_type": model_type,
                                    "min_val_loss": min_val_loss,
                                    "val_baseline": val_baseline,
                                    "validation_dataset": row["source_dataset"],
                                    "validation_loss": row["validation_loss"],
                                    "validation_baseline": row["validation_baseline"],
                                }
                            )

    # List to store result dictionaries
    results = []
    recursive_search(results_root_dir, results)
    return pd.DataFrame(results)

# %%
# Usage example:
# results_root_directory = "/om2/vast/yanglab/shared/qsimeon/worm-graph-experiments/version_1"
results_root_directory = "/home/qsimeon/om2/worm-graph/logs/hydra"  # DEBUG
combined_results_df = get_results_df(results_root_directory)
combined_results_df  # .head()  # To display the first few rows of the resulting DataFrame
# Out:
# Empty DataFrame
# Columns: []
# Index: []

# %% [markdown]
# # Model Scaling

# %% [markdown]
# # Scaling Number of Parameters

# %%
# %%cudf.pandas.profile


def print_best_model_info(df):
    """
    Prints the hidden size and number of parameters for the entry with the lowest min_val_loss
    for each unique model type in the DataFrame.

    Parameters:
    - df: A pandas DataFrame containing the model results.
    """
    model_types = df["model_type"].unique()
    for model_type in model_types:
        # Filter for the current model type
        model_df = df[df["model_type"] == model_type]

        # Find the index of the minimum validation loss
        idx_min_val_loss = model_df["min_val_loss"].idxmin()

        # Get the row for the minimum validation loss
        min_val_loss_row = model_df.loc[idx_min_val_loss]

        # Extract the hidden_size and num_parameters
        hidden_size = min_val_loss_row["hidden_size"]
        num_parameters = min_val_loss_row["num_parameters"]
        min_val_loss = min_val_loss_row["min_val_loss"]

        print(
            f"The {model_type} model achieved its lowest min_val_loss of {min_val_loss:.6f} "
            f"with a hidden_size of {hidden_size} and num_parameters of {num_parameters}."
        )

# %%
# %%cudf.pandas.profile


# We varied the hidden size as a "knob" to vary the number of parameters.
def parameters_scaling_plot(combined_results_df, legend_code, title=None):
    fig, ax = plt.subplots(figsize=(10, 5))
    ax.set_xscale("log")
    ax.set_yscale("log")
    ax.set_title(title, fontsize=14)

    # Group the DataFrame by 'model_type' and plot
    for model_type, group in combined_results_df.groupby("model_type"):
        # Skip if unrecognized type of model
        if model_type not in legend_code["model_labels"]:
            continue

        # Plot settings from legend_code
        model_label = legend_code["model_labels"][model_type]
        marker = legend_code["model_marker_code"][model_label]
        color = legend_code["model_color_code"][model_label]

        ### DEBUG ###
        # Do some filtering to remove some outliers
        group["num_parameters"] = group["num_parameters"][group["num_parameters"] < 1e8]
        group["min_val_loss"] = group["min_val_loss"][group["num_parameters"] < 1e8]
        ### DEBUG ###

        # Round the loss values to ignore precision differences
        group["min_val_loss"] = np.round(group["min_val_loss"], 4)

        # If the model is not 'Baseline' or 'Linear', perform lowess smoothing
        if len(group["num_parameters"].unique()) > 1:
            # Sort group for lowess
            sorted_group = group.sort_values("num_parameters")

            # Perform lowess smoothing
            lowess_result = lowess(
                sorted_group["min_val_loss"], sorted_group["num_parameters"], frac=0.1, it=0
            )
            # Plot lowess smooth curve
            ax.plot(lowess_result[:, 0], lowess_result[:, 1], color=color, lw=2, alpha=0.8)

        # Add random offsets to avoid overlaps
        x_offset = np.random.choice(2, size=len(group))
        y_offset = 0.0 * np.random.randn(len(group))

        # Scatter plot of validation loss vs. number of parameters
        ax.scatter(
            group["num_parameters"] + x_offset,
            group["min_val_loss"] + y_offset,
            marker=marker,
            s=20,
            color=color,
            label=model_label,
            alpha=0.7,
            edgecolor="black",
            linewidth=0.2,
        )

    # Plot baseline
    baseline = np.round(combined_results_df["val_baseline"], 4).unique()
    # for bsl in baseline:
    ax.axhline(
        y=min(baseline),
        label="Baseline",
        color="black",
        linestyle="--",
        linewidth=1,
        alpha=0.7,
    )

    # Create legends
    ax.legend(loc="best", title="Model architecture")
    ax.get_legend().get_title().set_fontstyle("italic")
    ax.set_xlabel("Num. trainable parameters", fontsize=12, fontweight="bold")
    ax.set_ylabel("Min. Validation Loss (MSE)", fontsize=12, fontweight="bold")

    # Show the plot
    plt.show()

# %% [markdown]
# `results_directory = "/om2/vast/yanglab/shared/qsimeon/worm-graph-experiments/version_1/upsample/num_parameters/experimental"`

# %%
# Retrieve the relevant results
results_directory = "/om2/vast/yanglab/shared/qsimeon/worm-graph-experiments/version_1/upsample/num_parameters/experimental"  # real worms AllExperimental
# results_directory = "/home/qsimeon/om2/worm-graph/logs/hydra"  # DEBUG
results_df = get_results_df(results_directory)
results_df  # .head()

# Example usage:
parameters_scaling_plot(results_df, leg_code, title="Experimental")

# Print the best model
print_best_model_info(results_df)
# Out:
# The NetworkLSTM model achieved its lowest min_val_loss of 0.014985 with a hidden_size of 240 and num_parameters of 699906.
# The FeatureFFNN model achieved its lowest min_val_loss of 0.025738 with a hidden_size of 986 and num_parameters of 1663190.
# The HippoSSM model achieved its lowest min_val_loss of 0.133892 with a hidden_size of 170 and num_parameters of 223766.
# The NetworkCTRNN model achieved its lowest min_val_loss of 0.022383 with a hidden_size of 1402 and num_parameters of 4877934.

# %% [markdown]
# `results_directory = "/om2/vast/yanglab/shared/qsimeon/worm-graph-experiments/version_1/upsample/num_parameters/synthetic"`

# %%
# Retrieve the relevant results
results_directory = "/om2/vast/yanglab/shared/qsimeon/worm-graph-experiments/version_1/upsample/num_parameters/synthetic/seed_1"  # synthetic data Sines
results_df = get_results_df(results_directory)
results_df  # .head()

# Example usage:
parameters_scaling_plot(results_df, leg_code, title="Sines")

# Print the best model
print_best_model_info(results_df)

# %%
# Retrieve the relevant results
results_directory = "/om2/vast/yanglab/shared/qsimeon/worm-graph-experiments/version_1/num_parameters/synthetic/seed_4"  # synthetic data Random Walk
results_df = get_results_df(results_directory)
results_df  # .head()

# Example usage:
parameters_scaling_plot(results_df, leg_code, title="Random Walk")

# Print the best model
print_best_model_info(results_df)

# %%
# # Retrieve the relevant results
# results_directory = "/om2/vast/yanglab/shared/qsimeon/worm-graph-experiments/version_1/num_parameters/synthetic/seed_6"  # synthetic data Shakespeare
# results_df = get_results_df(results_directory)
# results_df  # .head()

# # Example usage:
# parameters_scaling_plot(results_df, leg_code, title="Shakespeare")

# # Print the best model
# print_best_model_info(results_df)

# %% [markdown]
# # Data Scaling

# %% [markdown]
# ## Mixed Dataset Scaling

# %%
# %%cudf.pandas.profile


def mixed_scaling_plot(combined_results_df, legend_code, title=None):
    fig, ax = plt.subplots(1, 1, figsize=(10, 5))
    ax.set_xscale("log")
    ax.set_yscale("log")
    ax.set_title(title, fontsize=14)

    grouped_by_model = combined_results_df.groupby("model_type")
    for model_type, model_group in grouped_by_model:
        # Skip if unrecognized type of model
        if model_type not in legend_code["model_labels"]:
            continue

        # Obtain values for plotting
        nts = model_group["num_time_steps"]
        val_loss = model_group["min_val_loss"]
        baseline_loss = model_group["val_baseline"].iloc[0]  # Baseline is constant

        # Plot settings from legend_code
        model_label = legend_code["model_labels"][model_type]
        marker = legend_code["model_marker_code"][model_label]
        color = legend_code["model_color_code"][model_label]

        # Scatter plot
        ax.scatter(
            nts,
            val_loss,
            marker=marker,
            color=color,  # TODO: is this preventing the alpha from kicking in?
            s=20,
            label=None,
            alpha=0.7,
            linewidth=0.25,
            edgecolor="black",
        )

        # Baseline plot
        ax.axhline(
            baseline_loss,
            label="Baseline" if model_type == "FeatureFFNN" else "_nolegend_",
            color="black",
            alpha=0.5,
            linestyle="--",
            linewidth=1,
        )

        # Regression line
        slope, intercept, r_value, p_value, std_err = stats.linregress(
            np.log(nts), np.log(val_loss)
        )
        fit_label = f"y = {slope:.2f}x + {intercept:.1f}\n" f"$R^2={r_value**2:.2f}$"
        x_fit = np.linspace(nts.min(), nts.max(), 10000)
        y_fit = np.exp(intercept + slope * np.log(x_fit))

        ax.plot(x_fit, y_fit, color=color, label=fit_label, lw=2, alpha=0.8)

    # Handles and labels for first legend
    handles, labels = ax.get_legend_handles_labels()

    # Create the second legend
    legend2 = ax.legend(
        handles=legend_code["marker_legend"],
        loc="center right",
        bbox_to_anchor=(0.995, 0.85),
        title="Model architecture",
        fontsize="x-small",
    )
    ax.get_legend().get_title().set_fontstyle("italic")
    ax.get_legend().get_title().set_fontsize("x-small")
    ax.add_artist(legend2)

    # Display both legends
    ax.legend(
        handles,
        labels,
        loc="center left",
        bbox_to_anchor=(0.01, 0.25),
        fontsize="xx-small",
        ncols=2,
    )

    ax.set_xlabel("Num. train time steps", fontsize=12)
    ax.set_ylabel("Validation MSE Loss", fontsize=12)

    plt.show()

# %% [markdown]
# `results_directory = "/om2/vast/yanglab/shared/qsimeon/worm-graph-experiments/version_1/num_time_steps/experimental"`

# %%
# Retrieve the relevant results
results_directory = (
    "/om2/vast/yanglab/shared/qsimeon/worm-graph-experiments/version_1/num_time_steps/experimental"
)
results_df = get_results_df(results_directory)
results_df  # .head()

# Example usage
mixed_scaling_plot(results_df, leg_code, title="Experimental")

# %% [markdown]
# `results_directory = "/om2/vast/yanglab/shared/qsimeon/worm-graph-experiments/version_1/num_time_steps/synthetic"`

# %%
# Retrieve the relevant results
results_directory = "/om2/vast/yanglab/shared/qsimeon/worm-graph-experiments/version_1/num_time_steps/synthetic/seed_1"  # synthetic data Sines
results_df = get_results_df(results_directory)
results_df  # .head()

# Example usage
mixed_scaling_plot(results_df, leg_code, title="Sines")

# %%
# Retrieve the relevant results
results_directory = "/om2/vast/yanglab/shared/qsimeon/worm-graph-experiments/version_1/num_time_steps/synthetic/seed_4"  # synthetic data Random Walk
results_df = get_results_df(results_directory)
results_df  # .head()

# Example usage
mixed_scaling_plot(results_df, leg_code, title="Random Walk")

# %%
# # Retrieve the relevant results
# results_directory = "/om2/vast/yanglab/shared/qsimeon/worm-graph-experiments/version_1/num_time_steps/synthetic/seed_6"  # synthetic data Shakespeare
# results_df = get_results_df(results_directory)
# results_df  # .head()

# # Example usage
# mixed_scaling_plot(results_df, leg_code, title="Shakespeare")

# %% [markdown]
# # Individual Dataset Scaling

# %%
# %%cudf.pandas.profile


def individual_scaling_plot(combined_results_df, legend_code):
    # Sort model types to ensure Baseline is first
    model_types = combined_results_df["model_type"].unique()
    model_types_sorted = sorted(model_types, key=lambda x: x != "NaivePredictor")

    # Determine global y-axis limits
    global_min = combined_results_df["validation_loss"].min()
    global_max = combined_results_df["validation_loss"].max()

    # Create subplots
    fig, axs = plt.subplots(1, len(model_types_sorted), figsize=(15, 5), sharey=True)

    if len(model_types_sorted) > 1:
        axs = axs.flatten()
    else:
        axs = [axs]

    # Prepare a custom legend for the first subplot (Baseline)
    custom_legend_handles = []
    for dataset_name in legend_code["dataset_labels"].keys():
        color = legend_code["dataset_color_code"][dataset_name]
        custom_legend_handles.append(
            Line2D(
                [0],
                [0],
                marker="o",
                color=color,
                label=dataset_name,
                markersize=5,
                linestyle="None",
            )
        )
    # Add baseline legend entry
    custom_legend_handles.append(Line2D([0], [0], color="black", label="Baseline", linestyle="--"))

    for idx, model_type in enumerate(model_types_sorted):
        model_label = legend_code["model_labels"].get(model_type, model_type)
        model_group = combined_results_df[combined_results_df["model_type"] == model_type]

        ax = axs[idx]
        ax.set_xscale("log")
        ax.set_yscale("log")

        # Set the same y-axis limits for all subplots
        ax.set_ylim(global_min, global_max)

        for dataset_name, dataset_group in model_group.groupby("validation_dataset"):
            color = legend_code["dataset_color_code"][dataset_name]

            # Scatter plot for individual dataset
            ax.scatter(
                dataset_group["num_time_steps"],
                dataset_group["validation_loss"],
                s=7,
                color=color,
                label=dataset_name,
                alpha=0.3,
            )

            # Baseline horizontal line
            baseline_loss = dataset_group["validation_baseline"].iloc[0]
            ax.axhline(
                y=baseline_loss,
                color=color,
                linestyle="--",
                linewidth=1,
                alpha=0.7,
            )

            # Linear regression
            slope, intercept, r_value, p_value, std_err = stats.linregress(
                np.log(dataset_group["num_time_steps"]),
                np.log(dataset_group["validation_loss"]),
            )

            # Plot regression line
            x_reg = np.linspace(
                dataset_group["num_time_steps"].min(),
                dataset_group["num_time_steps"].max(),
                100,
            )
            y_reg = np.exp(intercept + slope * np.log(x_reg))
            ax.plot(x_reg, y_reg, color=color)

        ax.set_title(model_label, fontweight="bold")
        ax.set_xlabel("Num. train time steps")
        if idx == 0:
            ax.set_ylabel("Validation Loss")
            ax.legend(handles=custom_legend_handles, loc="best", title="Experimental datasets")
            ax.get_legend().get_title().set_fontstyle("italic")

    # Adjust the layout and display the plot
    plt.tight_layout()
    plt.show()

# %% [markdown]
# `results_directory = "/om2/vast/yanglab/shared/qsimeon/worm-graph-experiments/version_1/num_time_steps/experimental"`

# %%
# Retrieve the relevant results
results_directory = (
    "/om2/vast/yanglab/shared/qsimeon/worm-graph-experiments/version_1/num_time_steps/experimental"
)
results_df = get_results_df(results_directory)
results_df.head()

# Example usage:
individual_scaling_plot(results_df, leg_code)

# %% [markdown]
# Note: The next experiment is more of an investigation of the dataset properties rather than proerties of the ANN model. For that reason and to save time, we avoid running it for our paper deadline.

# %% [markdown]
# # Cross Dataset Generalization
# A heatmap showing the validation loss on all of the experimental datasets after a model has been trained on just one of the them.

# %%
# %%cudf.pandas.profile


def cross_dataset(combined_results_df, legend_code):
    dataset_labels = legend_code["dataset_labels"]
    model_labels = legend_code["model_labels"]

    # Prepare a DataFrame for the heatmap
    heatmap_data = pd.DataFrame(
        columns=dataset_labels.values(),
        index=pd.MultiIndex.from_product([model_labels.values(), dataset_labels.values()]),
    )

    # Fill the DataFrame with validation losses
    for (model_type, train_dataset), group in combined_results_df.groupby(
        ["model_type", "train_dataset"]
    ):
        for val_dataset in dataset_labels.keys():
            val_loss = group[group["validation_dataset"] == val_dataset]["validation_loss"].mean()
            heatmap_data.at[
                (model_labels[model_type], dataset_labels[train_dataset]),
                dataset_labels[val_dataset],
            ] = val_loss

    # Set up the figure for the heatmap
    num_models = len(model_labels)
    fig, ax = plt.subplots(figsize=(num_models * 4, 8))  # Adjust the size as needed

    # Create the heatmap
    sns.heatmap(
        heatmap_data.astype(float).unstack(level=0),
        annot=True,
        fmt=".2f",
        cmap="viridis",
        ax=ax,
        cbar_kws={"label": "Validation Loss (MSE)"},
    )

    # Set the title and axis labels
    ax.set_title("Cross Dataset Generalization", fontsize=16)
    ax.set_xlabel("Train Dataset", fontsize=14)
    ax.set_ylabel("Model Type and Validation Dataset", fontsize=14)

    plt.tight_layout()
    plt.show()

# %%
# Retrieve the relevant results
results_directory = (
    "/om2/vast/yanglab/shared/qsimeon/worm-graph-experiments/version_1/cross_dataset/experimental"
)
results_df = get_results_df(results_directory)
results_df  # .head()

# Usage example
cross_dataset(results_df, leg_code)
